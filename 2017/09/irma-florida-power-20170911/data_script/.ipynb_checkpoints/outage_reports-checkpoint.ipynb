# %%
# -*- coding: utf-8 -*-
# %matplotlib inline

import pandas as pd
import numpy as np
import math
import matplotlib as mplstyle
import matplotlib.pyplot as plt
import locale
import arrow
from locale import atof
from dateutil import parser
from datetime import datetime

# %%
def countyFips(countyCode):
    if (countyCode < 10):
        return '1200' + str(countyCode)
    if (countyCode < 99):
        return '120' + str(countyCode)
    if (countyCode > 100):
        return '12' + str(countyCode)

def removeWord(county):
    return county.replace(' County', '')

def properCase(county):
    if (county == 'DESOTO'):
        return 'DeSoto'
    else:
        return county.title()

# %%
# import data
df_fips_original = pd.read_csv('data/fips.csv')
df_latest = pd.read_csv('data/outage-reports-091117-4pm.csv')

# %%
# duplicate fips dataframe and build full fips codes with state + county num then drop unnecessary columns + reorder
df_fips = df_fips_original
df_fips['fips_code'] = df_fips_original['county_code'].apply(countyFips)
df_fips = df_fips.drop(['state','state_code','county_code','Unnamed: 4'], axis=1)

cols = ['fips_code','county_name']
df_fips = df_fips[cols]
df_fips['county_name'] = df_fips['county_name'].apply(removeWord)
# df_fips

# %%
df_latest = df_latest.drop([0,1])
df_latest.columns = df_latest.iloc[0]
df_latestClean = df_latest.reset_index().drop([0])
df_latestClean = df_latestClean.drop(['index'], axis=1)

# %%
list(df_latestClean)
df_latestClean.columns = ['county_name','fpl_total','fpl_out','fpl_out_pct','duke_total','duke_out','duke_pct','gulf_total','gulf_out','gulf_pct','tampa_total','tampa_out','tampa_pct','fpu_total','fpu_out','fpu_pct','coops_total','coops_out','coops_pct','muni_total','muni_out','muni_pct','overall_out','overall_total','overall_with_pct','overall_out_pct'
]
df_latestClean = df_latestClean.drop([68])
df_latestClean
# Out:
#      county_name  fpl_total  fpl_out fpl_out_pct duke_total duke_out duke_pct  \
# 1        ALACHUA      1,300    1,300        100%      4,880    3,056      63%
# 2          BAKER      5,400    4,460         83%        NaN      NaN      NaN
# 3            BAY        NaN      NaN         NaN      2,273    1,241      55%
# 4       BRADFORD      4,100    3,870         94%        NaN      NaN      NaN
# 5        BREVARD    307,600  225,490         73%         16        9      56%
# 6        BROWARD    933,300  629,080         67%        NaN      NaN      NaN
# 7        CALHOUN        NaN      NaN         NaN        NaN      NaN      NaN
# 8      CHARLOTTE    114,100   65,870         58%        NaN      NaN      NaN
# 9         CITRUS        NaN      NaN         NaN     46,697   33,755      72%
# 10          CLAY        900      900        100%        NaN      NaN      NaN
# 11       COLLIER    210,700  200,930         95%        NaN      NaN      NaN
# 12      COLUMBIA     14,000   14,000        100%        566      323      57%
# 13        DESOTO     16,600   13,960         84%        NaN      NaN      NaN
# 14         DIXIE        NaN      NaN         NaN      1,800    1,057      59%
# 15         DUVAL         10       10        100%        NaN      NaN      NaN
# 16      ESCAMBIA        NaN      NaN         NaN        NaN      NaN      NaN
# 17       FLAGLER     58,000   49,640         86%         16       13      81%
# 18      FRANKLIN        NaN      NaN         NaN     10,202    5,775      57%
# 19       GADSDEN        NaN      NaN         NaN        NaN      NaN      NaN
# 20     GILCHRIST        NaN      NaN         NaN      1,637      936      57%
# 21        GLADES      3,400    2,420         71%        NaN      NaN      NaN
# 22          GULF        NaN      NaN         NaN      6,470    3,602      56%
# 23      HAMILTON        NaN      NaN         NaN      2,927    1,723      59%
# 24        HARDEE         40       30         75%      2,671    2,680     100%
# 25        HENDRY      9,700    9,700        100%        NaN      NaN      NaN
# 26      HERNANDO        NaN      NaN         NaN     11,341    7,618      67%
# 27     HIGHLANDS        600      420         70%     54,209   53,952     100%
# 28  HILLSBOROUGH        NaN      NaN         NaN         25       19      76%
# 29        HOLMES        NaN      NaN         NaN        NaN      NaN      NaN
# 30  INDIAN RIVER     56,300   42,240         75%        NaN      NaN      NaN
# ..           ...        ...      ...         ...        ...      ...      ...
# 38       LIBERTY        NaN      NaN         NaN        NaN      NaN      NaN
# 39       MADISON        NaN      NaN         NaN      3,811    2,243      59%
# 40       MANATEE    184,900  106,620         58%        NaN      NaN      NaN
# 41        MARION        NaN      NaN         NaN     65,525   54,513      83%
# 42        MARTIN     93,400   69,870         75%        NaN      NaN      NaN
# 43    MIAMI-DADE  1,114,000  802,430         72%        NaN      NaN      NaN
# 44        MONROE         90       90        100%        NaN      NaN      NaN
# 45        NASSAU     21,800   20,820         96%        NaN      NaN      NaN
# 46      OKALOOSA        NaN      NaN         NaN        NaN      NaN      NaN
# 47    OKEECHOBEE     20,000   19,200         96%        NaN      NaN      NaN
# 48        ORANGE         10       10        100%    369,171  226,228      61%
# 49       OSCEOLA         10       10        100%     48,065   23,979      50%
# 50    PALM BEACH    739,000  509,490         69%        NaN      NaN      NaN
# 51         PASCO        NaN      NaN         NaN    139,992  102,846      73%
# 52      PINELLAS        NaN      NaN         NaN    540,933  428,475      79%
# 53          POLK        NaN      NaN         NaN    100,519   66,469      66%
# 54        PUTNAM     20,100   18,920         94%        NaN      NaN      NaN
# 55    SANTA ROSA        NaN      NaN         NaN        NaN      NaN      NaN
# 56      SARASOTA    263,800  170,120         64%        NaN      NaN      NaN
# 57      SEMINOLE     54,400   41,650         77%    156,103  116,255      74%
# 58     ST. JOHNS     86,800   75,930         87%        NaN      NaN      NaN
# 59     ST. LUCIE    126,200   92,990         74%        NaN      NaN      NaN
# 60        SUMTER        NaN      NaN         NaN     10,171    8,789      86%
# 61      SUWANNEE      5,100    4,530         89%        797      466      58%
# 62        TAYLOR        NaN      NaN         NaN      6,026    3,491      58%
# 63         UNION      1,700    1,150         68%        NaN      NaN      NaN
# 64       VOLUSIA    176,800  125,730         71%     81,055   68,131      84%
# 65       WAKULLA        NaN      NaN         NaN      6,814    3,844      56%
# 66        WALTON        NaN      NaN         NaN        NaN      NaN      NaN
# 67    WASHINGTON        NaN      NaN         NaN        NaN      NaN      NaN
#
#    gulf_total gulf_out gulf_pct       ...       coops_total coops_out  \
# 1         NaN      NaN      NaN       ...            23,226    19,933
# 2         NaN      NaN      NaN       ...             5,963     5,832
# 3     101,709      101       0%       ...            11,647       161
# 4         NaN      NaN      NaN       ...             5,864     5,455
# 5         NaN      NaN      NaN       ...             3,028       887
# 6         NaN      NaN      NaN       ...                54        54
# 7         NaN      NaN      NaN       ...             1,697       283
# 8         NaN      NaN      NaN       ...               858       840
# 9         NaN      NaN      NaN       ...            41,017    35,310
# 10        NaN      NaN      NaN       ...            80,056    66,307
# 11        NaN      NaN      NaN       ...            35,211    35,211
# 12        NaN      NaN      NaN       ...            18,797    16,411
# 13        NaN      NaN      NaN       ...               965       882
# 14        NaN      NaN      NaN       ...             8,207     6,483
# 15        NaN      NaN      NaN       ...                17        17
# 16    152,699       78       0%       ...             3,437         0
# 17        NaN      NaN      NaN       ...                 3         3
# 18        NaN      NaN      NaN       ...               NaN       NaN
# 19        NaN      NaN      NaN       ...            14,972     3,128
# 20        NaN      NaN      NaN       ...             7,263     6,047
# 21        NaN      NaN      NaN       ...             2,942     2,940
# 22        NaN      NaN      NaN       ...             4,439       141
# 23        NaN      NaN      NaN       ...             3,785     3,487
# 24        NaN      NaN      NaN       ...             6,846     5,835
# 25        NaN      NaN      NaN       ...             4,778     4,778
# 26        NaN      NaN      NaN       ...            83,599    50,280
# 27        NaN      NaN      NaN       ...             7,647     7,638
# 28        NaN      NaN      NaN       ...             1,148     1,106
# 29      2,581        1       0%       ...             7,842         2
# 30        NaN      NaN      NaN       ...               215       172
# ..        ...      ...      ...       ...               ...       ...
# 38        NaN      NaN      NaN       ...             3,289     1,849
# 39        NaN      NaN      NaN       ...             6,897     4,541
# 40        NaN      NaN      NaN       ...            24,857     9,868
# 41        NaN      NaN      NaN       ...            73,611    48,230
# 42        NaN      NaN      NaN       ...               NaN       NaN
# 43        NaN      NaN      NaN       ...               NaN       NaN
# 44        NaN      NaN      NaN       ...            32,500    21,666
# 45        NaN      NaN      NaN       ...             6,920     6,844
# 46     92,602      110       0%       ...            15,809         0
# 47        NaN      NaN      NaN       ...             2,790     2,790
# 48        NaN      NaN      NaN       ...               NaN       NaN
# 49        NaN      NaN      NaN       ...               914       746
# 50        NaN      NaN      NaN       ...               NaN       NaN
# 51        NaN      NaN      NaN       ...           106,267    71,990
# 52        NaN      NaN      NaN       ...               NaN       NaN
# 53        NaN      NaN      NaN       ...             5,797     5,490
# 54        NaN      NaN      NaN       ...            21,166    17,596
# 55     68,697        2       0%       ...             7,559         0
# 56        NaN      NaN      NaN       ...                35        35
# 57        NaN      NaN      NaN       ...               NaN       NaN
# 58        NaN      NaN      NaN       ...               NaN       NaN
# 59        NaN      NaN      NaN       ...               NaN       NaN
# 60        NaN      NaN      NaN       ...            61,939    15,380
# 61        NaN      NaN      NaN       ...            16,860    15,932
# 62        NaN      NaN      NaN       ...             6,890     5,581
# 63        NaN      NaN      NaN       ...             3,738     3,424
# 64        NaN      NaN      NaN       ...             2,151     1,928
# 65        NaN      NaN      NaN       ...             8,657     4,849
# 66     23,143        4       0%       ...            36,333        48
# 67      6,481      232       4%       ...             6,609       373
#
#    coops_pct muni_total muni_out muni_pct overall_out overall_total  \
# 1        86%    100,626   42,321      42%      66,610       130,032
# 2        98%        NaN      NaN      NaN      10,292        11,363
# 3         1%        NaN      NaN      NaN       1,503       115,629
# 4        93%      2,685    2,685     100%      12,010        12,649
# 5        29%        NaN      NaN      NaN     226,386       310,644
# 6       100%        NaN      NaN      NaN     629,134       933,354
# 7        17%      1,314      300      23%         837         3,936
# 8        98%        NaN      NaN      NaN      66,710       114,958
# 9        86%        NaN      NaN      NaN      69,065        87,714
# 10       83%     13,883    6,042      44%      73,249        94,839
# 11      100%        NaN      NaN      NaN     236,141       245,911
# 12       87%        NaN      NaN      NaN      30,734        33,363
# 13       91%        NaN      NaN      NaN      14,842        17,565
# 14       79%        NaN      NaN      NaN       7,540        10,007
# 15      100%    462,619  252,608      55%     252,635       462,646
# 16        0%        NaN      NaN      NaN          78       156,136
# 17      100%        NaN      NaN      NaN      49,656        58,019
# 18       NaN        NaN      NaN      NaN       5,775        10,202
# 19       21%      7,322      336       5%       3,464        22,294
# 20       83%        NaN      NaN      NaN       6,983         8,900
# 21      100%        912      912     100%       6,272         7,254
# 22        3%        NaN      NaN      NaN       3,743        10,909
# 23       92%        NaN      NaN      NaN       5,210         6,712
# 24       85%      2,734    2,734     100%      11,279        12,291
# 25      100%      4,272    4,272     100%      18,750        18,750
# 26       60%        NaN      NaN      NaN      57,898        94,940
# 27      100%        NaN      NaN      NaN      62,010        62,456
# 28       96%        NaN      NaN      NaN     263,631       632,953
# 29        0%        NaN      NaN      NaN           3        10,423
# 30       80%     35,030   25,790      74%      68,202        91,545
# ..       ...        ...      ...      ...         ...           ...
# 38       56%        NaN      NaN      NaN       1,850         4,058
# 39       66%        NaN      NaN      NaN       6,784        10,708
# 40       40%        NaN      NaN      NaN     116,488       209,757
# 41       66%     49,955   40,742      82%     143,485       189,091
# 42       NaN        NaN      NaN      NaN      69,870        93,400
# 43       NaN     23,086   21,000      91%     823,430     1,137,086
# 44       67%     31,183   31,183     100%      52,939        63,773
# 45       99%        NaN      NaN      NaN      43,740        44,796
# 46        0%        NaN      NaN      NaN         110       108,411
# 47      100%        NaN      NaN      NaN      21,990        22,790
# 48       NaN    211,091  130,143      62%     356,381       580,272
# 49       82%    103,742   14,553      14%      39,288       152,731
# 50       NaN     27,847   24,500      88%     533,990       766,847
# 51       68%        NaN      NaN      NaN     189,194       270,095
# 52       NaN        NaN      NaN      NaN     429,202       551,917
# 53       95%    139,134   84,695      61%     207,316       330,732
# 54       83%        NaN      NaN      NaN      36,516        41,266
# 55        0%        NaN      NaN      NaN           2        76,256
# 56      100%        NaN      NaN      NaN     170,155       263,835
# 57       NaN        NaN      NaN      NaN     157,905       210,503
# 58       NaN     43,969   31,200      71%     107,130       130,769
# 59       NaN     27,630   15,966      58%     108,956       153,830
# 60       25%      1,500    1,500     100%      25,669        73,610
# 61       94%        NaN      NaN      NaN      20,928        22,757
# 62       81%        NaN      NaN      NaN       9,072        12,916
# 63       92%        NaN      NaN      NaN       4,574         5,438
# 64       90%     26,539   26,539     100%     222,328       286,545
# 65       56%        NaN      NaN      NaN       8,693        15,471
# 66        0%        NaN      NaN      NaN          52        59,476
# 67        6%        NaN      NaN      NaN         605        13,090
#
#    overall_with_pct overall_out_pct
# 1               49%             51%
# 2                9%             91%
# 3               99%              1%
# 4                5%             95%
# 5               27%             73%
# 6               33%             67%
# 7               79%             21%
# 8               42%             58%
# 9               21%             79%
# 10              23%             77%
# 11               4%             96%
# 12               8%             92%
# 13              16%             84%
# 14              25%             75%
# 15              45%             55%
# 16             100%              0%
# 17              14%             86%
# 18              43%             57%
# 19              84%             16%
# 20              22%             78%
# 21              14%             86%
# 22              66%             34%
# 23              22%             78%
# 24               8%             92%
# 25               0%            100%
# 26              39%             61%
# 27               1%             99%
# 28              58%             42%
# 29             100%              0%
# 30              25%             75%
# ..              ...             ...
# 38              54%             46%
# 39              37%             63%
# 40              44%             56%
# 41              24%             76%
# 42              25%             75%
# 43              28%             72%
# 44              17%             83%
# 45               2%             98%
# 46             100%              0%
# 47               4%             96%
# 48              39%             61%
# 49              74%             26%
# 50              30%             70%
# 51              30%             70%
# 52              22%             78%
# 53              37%             63%
# 54              12%             88%
# 55             100%              0%
# 56              36%             64%
# 57              25%             75%
# 58              18%             82%
# 59              29%             71%
# 60              65%             35%
# 61               8%             92%
# 62              30%             70%
# 63              16%             84%
# 64              22%             78%
# 65              44%             56%
# 66             100%              0%
# 67              95%              5%
#
# [67 rows x 26 columns]

# %%
df_latestClean['county_name'] = df_latestClean['county_name'].apply(properCase)
df_latestClean
# Out:
#      county_name  fpl_total  fpl_out fpl_out_pct duke_total duke_out duke_pct  \
# 1        Alachua      1,300    1,300        100%      4,880    3,056      63%
# 2          Baker      5,400    4,460         83%        NaN      NaN      NaN
# 3            Bay        NaN      NaN         NaN      2,273    1,241      55%
# 4       Bradford      4,100    3,870         94%        NaN      NaN      NaN
# 5        Brevard    307,600  225,490         73%         16        9      56%
# 6        Broward    933,300  629,080         67%        NaN      NaN      NaN
# 7        Calhoun        NaN      NaN         NaN        NaN      NaN      NaN
# 8      Charlotte    114,100   65,870         58%        NaN      NaN      NaN
# 9         Citrus        NaN      NaN         NaN     46,697   33,755      72%
# 10          Clay        900      900        100%        NaN      NaN      NaN
# 11       Collier    210,700  200,930         95%        NaN      NaN      NaN
# 12      Columbia     14,000   14,000        100%        566      323      57%
# 13        DeSoto     16,600   13,960         84%        NaN      NaN      NaN
# 14         Dixie        NaN      NaN         NaN      1,800    1,057      59%
# 15         Duval         10       10        100%        NaN      NaN      NaN
# 16      Escambia        NaN      NaN         NaN        NaN      NaN      NaN
# 17       Flagler     58,000   49,640         86%         16       13      81%
# 18      Franklin        NaN      NaN         NaN     10,202    5,775      57%
# 19       Gadsden        NaN      NaN         NaN        NaN      NaN      NaN
# 20     Gilchrist        NaN      NaN         NaN      1,637      936      57%
# 21        Glades      3,400    2,420         71%        NaN      NaN      NaN
# 22          Gulf        NaN      NaN         NaN      6,470    3,602      56%
# 23      Hamilton        NaN      NaN         NaN      2,927    1,723      59%
# 24        Hardee         40       30         75%      2,671    2,680     100%
# 25        Hendry      9,700    9,700        100%        NaN      NaN      NaN
# 26      Hernando        NaN      NaN         NaN     11,341    7,618      67%
# 27     Highlands        600      420         70%     54,209   53,952     100%
# 28  Hillsborough        NaN      NaN         NaN         25       19      76%
# 29        Holmes        NaN      NaN         NaN        NaN      NaN      NaN
# 30  Indian River     56,300   42,240         75%        NaN      NaN      NaN
# ..           ...        ...      ...         ...        ...      ...      ...
# 38       Liberty        NaN      NaN         NaN        NaN      NaN      NaN
# 39       Madison        NaN      NaN         NaN      3,811    2,243      59%
# 40       Manatee    184,900  106,620         58%        NaN      NaN      NaN
# 41        Marion        NaN      NaN         NaN     65,525   54,513      83%
# 42        Martin     93,400   69,870         75%        NaN      NaN      NaN
# 43    Miami-Dade  1,114,000  802,430         72%        NaN      NaN      NaN
# 44        Monroe         90       90        100%        NaN      NaN      NaN
# 45        Nassau     21,800   20,820         96%        NaN      NaN      NaN
# 46      Okaloosa        NaN      NaN         NaN        NaN      NaN      NaN
# 47    Okeechobee     20,000   19,200         96%        NaN      NaN      NaN
# 48        Orange         10       10        100%    369,171  226,228      61%
# 49       Osceola         10       10        100%     48,065   23,979      50%
# 50    Palm Beach    739,000  509,490         69%        NaN      NaN      NaN
# 51         Pasco        NaN      NaN         NaN    139,992  102,846      73%
# 52      Pinellas        NaN      NaN         NaN    540,933  428,475      79%
# 53          Polk        NaN      NaN         NaN    100,519   66,469      66%
# 54        Putnam     20,100   18,920         94%        NaN      NaN      NaN
# 55    Santa Rosa        NaN      NaN         NaN        NaN      NaN      NaN
# 56      Sarasota    263,800  170,120         64%        NaN      NaN      NaN
# 57      Seminole     54,400   41,650         77%    156,103  116,255      74%
# 58     St. Johns     86,800   75,930         87%        NaN      NaN      NaN
# 59     St. Lucie    126,200   92,990         74%        NaN      NaN      NaN
# 60        Sumter        NaN      NaN         NaN     10,171    8,789      86%
# 61      Suwannee      5,100    4,530         89%        797      466      58%
# 62        Taylor        NaN      NaN         NaN      6,026    3,491      58%
# 63         Union      1,700    1,150         68%        NaN      NaN      NaN
# 64       Volusia    176,800  125,730         71%     81,055   68,131      84%
# 65       Wakulla        NaN      NaN         NaN      6,814    3,844      56%
# 66        Walton        NaN      NaN         NaN        NaN      NaN      NaN
# 67    Washington        NaN      NaN         NaN        NaN      NaN      NaN
#
#    gulf_total gulf_out gulf_pct       ...       coops_total coops_out  \
# 1         NaN      NaN      NaN       ...            23,226    19,933
# 2         NaN      NaN      NaN       ...             5,963     5,832
# 3     101,709      101       0%       ...            11,647       161
# 4         NaN      NaN      NaN       ...             5,864     5,455
# 5         NaN      NaN      NaN       ...             3,028       887
# 6         NaN      NaN      NaN       ...                54        54
# 7         NaN      NaN      NaN       ...             1,697       283
# 8         NaN      NaN      NaN       ...               858       840
# 9         NaN      NaN      NaN       ...            41,017    35,310
# 10        NaN      NaN      NaN       ...            80,056    66,307
# 11        NaN      NaN      NaN       ...            35,211    35,211
# 12        NaN      NaN      NaN       ...            18,797    16,411
# 13        NaN      NaN      NaN       ...               965       882
# 14        NaN      NaN      NaN       ...             8,207     6,483
# 15        NaN      NaN      NaN       ...                17        17
# 16    152,699       78       0%       ...             3,437         0
# 17        NaN      NaN      NaN       ...                 3         3
# 18        NaN      NaN      NaN       ...               NaN       NaN
# 19        NaN      NaN      NaN       ...            14,972     3,128
# 20        NaN      NaN      NaN       ...             7,263     6,047
# 21        NaN      NaN      NaN       ...             2,942     2,940
# 22        NaN      NaN      NaN       ...             4,439       141
# 23        NaN      NaN      NaN       ...             3,785     3,487
# 24        NaN      NaN      NaN       ...             6,846     5,835
# 25        NaN      NaN      NaN       ...             4,778     4,778
# 26        NaN      NaN      NaN       ...            83,599    50,280
# 27        NaN      NaN      NaN       ...             7,647     7,638
# 28        NaN      NaN      NaN       ...             1,148     1,106
# 29      2,581        1       0%       ...             7,842         2
# 30        NaN      NaN      NaN       ...               215       172
# ..        ...      ...      ...       ...               ...       ...
# 38        NaN      NaN      NaN       ...             3,289     1,849
# 39        NaN      NaN      NaN       ...             6,897     4,541
# 40        NaN      NaN      NaN       ...            24,857     9,868
# 41        NaN      NaN      NaN       ...            73,611    48,230
# 42        NaN      NaN      NaN       ...               NaN       NaN
# 43        NaN      NaN      NaN       ...               NaN       NaN
# 44        NaN      NaN      NaN       ...            32,500    21,666
# 45        NaN      NaN      NaN       ...             6,920     6,844
# 46     92,602      110       0%       ...            15,809         0
# 47        NaN      NaN      NaN       ...             2,790     2,790
# 48        NaN      NaN      NaN       ...               NaN       NaN
# 49        NaN      NaN      NaN       ...               914       746
# 50        NaN      NaN      NaN       ...               NaN       NaN
# 51        NaN      NaN      NaN       ...           106,267    71,990
# 52        NaN      NaN      NaN       ...               NaN       NaN
# 53        NaN      NaN      NaN       ...             5,797     5,490
# 54        NaN      NaN      NaN       ...            21,166    17,596
# 55     68,697        2       0%       ...             7,559         0
# 56        NaN      NaN      NaN       ...                35        35
# 57        NaN      NaN      NaN       ...               NaN       NaN
# 58        NaN      NaN      NaN       ...               NaN       NaN
# 59        NaN      NaN      NaN       ...               NaN       NaN
# 60        NaN      NaN      NaN       ...            61,939    15,380
# 61        NaN      NaN      NaN       ...            16,860    15,932
# 62        NaN      NaN      NaN       ...             6,890     5,581
# 63        NaN      NaN      NaN       ...             3,738     3,424
# 64        NaN      NaN      NaN       ...             2,151     1,928
# 65        NaN      NaN      NaN       ...             8,657     4,849
# 66     23,143        4       0%       ...            36,333        48
# 67      6,481      232       4%       ...             6,609       373
#
#    coops_pct muni_total muni_out muni_pct overall_out overall_total  \
# 1        86%    100,626   42,321      42%      66,610       130,032
# 2        98%        NaN      NaN      NaN      10,292        11,363
# 3         1%        NaN      NaN      NaN       1,503       115,629
# 4        93%      2,685    2,685     100%      12,010        12,649
# 5        29%        NaN      NaN      NaN     226,386       310,644
# 6       100%        NaN      NaN      NaN     629,134       933,354
# 7        17%      1,314      300      23%         837         3,936
# 8        98%        NaN      NaN      NaN      66,710       114,958
# 9        86%        NaN      NaN      NaN      69,065        87,714
# 10       83%     13,883    6,042      44%      73,249        94,839
# 11      100%        NaN      NaN      NaN     236,141       245,911
# 12       87%        NaN      NaN      NaN      30,734        33,363
# 13       91%        NaN      NaN      NaN      14,842        17,565
# 14       79%        NaN      NaN      NaN       7,540        10,007
# 15      100%    462,619  252,608      55%     252,635       462,646
# 16        0%        NaN      NaN      NaN          78       156,136
# 17      100%        NaN      NaN      NaN      49,656        58,019
# 18       NaN        NaN      NaN      NaN       5,775        10,202
# 19       21%      7,322      336       5%       3,464        22,294
# 20       83%        NaN      NaN      NaN       6,983         8,900
# 21      100%        912      912     100%       6,272         7,254
# 22        3%        NaN      NaN      NaN       3,743        10,909
# 23       92%        NaN      NaN      NaN       5,210         6,712
# 24       85%      2,734    2,734     100%      11,279        12,291
# 25      100%      4,272    4,272     100%      18,750        18,750
# 26       60%        NaN      NaN      NaN      57,898        94,940
# 27      100%        NaN      NaN      NaN      62,010        62,456
# 28       96%        NaN      NaN      NaN     263,631       632,953
# 29        0%        NaN      NaN      NaN           3        10,423
# 30       80%     35,030   25,790      74%      68,202        91,545
# ..       ...        ...      ...      ...         ...           ...
# 38       56%        NaN      NaN      NaN       1,850         4,058
# 39       66%        NaN      NaN      NaN       6,784        10,708
# 40       40%        NaN      NaN      NaN     116,488       209,757
# 41       66%     49,955   40,742      82%     143,485       189,091
# 42       NaN        NaN      NaN      NaN      69,870        93,400
# 43       NaN     23,086   21,000      91%     823,430     1,137,086
# 44       67%     31,183   31,183     100%      52,939        63,773
# 45       99%        NaN      NaN      NaN      43,740        44,796
# 46        0%        NaN      NaN      NaN         110       108,411
# 47      100%        NaN      NaN      NaN      21,990        22,790
# 48       NaN    211,091  130,143      62%     356,381       580,272
# 49       82%    103,742   14,553      14%      39,288       152,731
# 50       NaN     27,847   24,500      88%     533,990       766,847
# 51       68%        NaN      NaN      NaN     189,194       270,095
# 52       NaN        NaN      NaN      NaN     429,202       551,917
# 53       95%    139,134   84,695      61%     207,316       330,732
# 54       83%        NaN      NaN      NaN      36,516        41,266
# 55        0%        NaN      NaN      NaN           2        76,256
# 56      100%        NaN      NaN      NaN     170,155       263,835
# 57       NaN        NaN      NaN      NaN     157,905       210,503
# 58       NaN     43,969   31,200      71%     107,130       130,769
# 59       NaN     27,630   15,966      58%     108,956       153,830
# 60       25%      1,500    1,500     100%      25,669        73,610
# 61       94%        NaN      NaN      NaN      20,928        22,757
# 62       81%        NaN      NaN      NaN       9,072        12,916
# 63       92%        NaN      NaN      NaN       4,574         5,438
# 64       90%     26,539   26,539     100%     222,328       286,545
# 65       56%        NaN      NaN      NaN       8,693        15,471
# 66        0%        NaN      NaN      NaN          52        59,476
# 67        6%        NaN      NaN      NaN         605        13,090
#
#    overall_with_pct overall_out_pct
# 1               49%             51%
# 2                9%             91%
# 3               99%              1%
# 4                5%             95%
# 5               27%             73%
# 6               33%             67%
# 7               79%             21%
# 8               42%             58%
# 9               21%             79%
# 10              23%             77%
# 11               4%             96%
# 12               8%             92%
# 13              16%             84%
# 14              25%             75%
# 15              45%             55%
# 16             100%              0%
# 17              14%             86%
# 18              43%             57%
# 19              84%             16%
# 20              22%             78%
# 21              14%             86%
# 22              66%             34%
# 23              22%             78%
# 24               8%             92%
# 25               0%            100%
# 26              39%             61%
# 27               1%             99%
# 28              58%             42%
# 29             100%              0%
# 30              25%             75%
# ..              ...             ...
# 38              54%             46%
# 39              37%             63%
# 40              44%             56%
# 41              24%             76%
# 42              25%             75%
# 43              28%             72%
# 44              17%             83%
# 45               2%             98%
# 46             100%              0%
# 47               4%             96%
# 48              39%             61%
# 49              74%             26%
# 50              30%             70%
# 51              30%             70%
# 52              22%             78%
# 53              37%             63%
# 54              12%             88%
# 55             100%              0%
# 56              36%             64%
# 57              25%             75%
# 58              18%             82%
# 59              29%             71%
# 60              65%             35%
# 61               8%             92%
# 62              30%             70%
# 63              16%             84%
# 64              22%             78%
# 65              44%             56%
# 66             100%              0%
# 67              95%              5%
#
# [67 rows x 26 columns]

# %%
df_dataMerge = df_fips.merge(df_latestClean,on='county_name',how='outer')
df_dataMerge = df_dataMerge.rename(columns={'fips_code':'county_fips'})
df_dataMerge
df_dataMerge.to_csv('data/finalData.csv')
