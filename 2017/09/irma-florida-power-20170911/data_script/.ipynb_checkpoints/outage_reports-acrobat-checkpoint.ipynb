# %%
# -*- coding: utf-8 -*-
# %matplotlib inline

import pandas as pd
import numpy as np
import math
import matplotlib as mplstyle
import matplotlib.pyplot as plt
import locale
import arrow
from locale import atof
from dateutil import parser
from datetime import datetime

# %%
def countyFips(countyCode):
    if (countyCode < 10):
        return '1200' + str(countyCode)
    if (countyCode < 99):
        return '120' + str(countyCode)
    if (countyCode > 100):
        return '12' + str(countyCode)

def removeWord(county):
    return county.replace(' County', '')

def properCase(county):
    if (county == 'DESOTO'):
        return 'DeSoto'
    else:
        return county.title()

# %%
# import data
df_fips_original = pd.read_csv('data/fips.csv')
df_latest = pd.read_csv('data/outage_reports-091117-6pm.csv')

# %%
# duplicate fips dataframe and build full fips codes with state + county num then drop unnecessary columns + reorder
df_fips = df_fips_original
df_fips['fips_code'] = df_fips_original['county_code'].apply(countyFips)
df_fips = df_fips.drop(['state','state_code','county_code','Unnamed: 4'], axis=1)

cols = ['fips_code','county_name']
df_fips = df_fips[cols]
df_fips['county_name'] = df_fips['county_name'].apply(removeWord)
# df_fips

# %%
df_latest = df_latest.drop([0,1])
df_latest.columns = df_latest.iloc[0]
df_latestClean = df_latest.reset_index().drop([0])
df_latestClean = df_latestClean.drop(['index'], axis=1)

# %%
list(df_latestClean)
df_latestClean.columns = ['county_name','fpl_total','fpl_out','fpl_out_pct','duke_total','duke_out','duke_pct','gulf_total','gulf_out','gulf_pct','tampa_total','tampa_out','tampa_pct','fpu_total','fpu_out','fpu_pct','coops_total','coops_out','coops_pct','muni_total','muni_out','muni_pct','overall_out','overall_total','overall_with_pct','overall_out_pct'
]
df_latestClean = df_latestClean.drop([68])
df_latestClean
# Out:
#      county_name  fpl_total  fpl_out fpl_out_pct duke_total duke_out duke_pct  \
# 1        ALACHUA      1,300      860         66%      4,880    3,076      63%
# 2          BAKER      5,400    4,320         80%        NaN      NaN      NaN
# 3            BAY        NaN      NaN         NaN      2,273    1,252      55%
# 4       BRADFORD      4,100    3,950         96%        NaN      NaN      NaN
# 5        BREVARD    307,600  212,320         69%         16        9      56%
# 6        BROWARD    933,300  601,370         64%        NaN      NaN      NaN
# 7        CALHOUN        NaN      NaN         NaN        NaN      NaN      NaN
# 8      CHARLOTTE    114,100   61,780         54%        NaN      NaN      NaN
# 9         CITRUS        NaN      NaN         NaN     46,697   33,959      73%
# 10          CLAY        900      460         51%        NaN      NaN      NaN
# 11       COLLIER    210,700  196,800         93%        NaN      NaN      NaN
# 12      COLUMBIA     14,000   13,610         97%        566      326      58%
# 13        DESOTO     16,600   12,830         77%        NaN      NaN      NaN
# 14         DIXIE        NaN      NaN         NaN      1,800    1,066      59%
# 15         DUVAL         10       10        100%        NaN      NaN      NaN
# 16      ESCAMBIA        NaN      NaN         NaN        NaN      NaN      NaN
# 17       FLAGLER     58,000   46,800         81%         16       13      81%
# 18      FRANKLIN        NaN      NaN         NaN     10,202    5,824      57%
# 19       GADSDEN        NaN      NaN         NaN        NaN      NaN      NaN
# 20     GILCHRIST        NaN      NaN         NaN      1,637      944      58%
# 21        GLADES      3,400    2,350         69%        NaN      NaN      NaN
# 22          GULF        NaN      NaN         NaN      6,470    3,633      56%
# 23      HAMILTON        NaN      NaN         NaN      2,927    1,737      59%
# 24        HARDEE         40       30         75%      2,671    2,661     100%
# 25        HENDRY      9,700    9,700        100%        NaN      NaN      NaN
# 26      HERNANDO        NaN      NaN         NaN     11,341    8,364      74%
# 27     HIGHLANDS        600      490         82%     54,209   53,865      99%
# 28  HILLSBOROUGH        NaN      NaN         NaN         25       19      76%
# 29        HOLMES        NaN      NaN         NaN        NaN      NaN      NaN
# 30  INDIAN RIVER     56,300   41,090         73%        NaN      NaN      NaN
# ..           ...        ...      ...         ...        ...      ...      ...
# 38       LIBERTY        NaN      NaN         NaN        NaN      NaN      NaN
# 39       MADISON        NaN      NaN         NaN      3,811    2,262      59%
# 40       MANATEE    184,900  104,580         57%        NaN      NaN      NaN
# 41        MARION        NaN      NaN         NaN     65,525   54,629      83%
# 42        MARTIN     93,400   63,200         68%        NaN      NaN      NaN
# 43    MIAMI-DADE  1,114,000  782,900         70%        NaN      NaN      NaN
# 44        MONROE         90       90        100%        NaN      NaN      NaN
# 45        NASSAU     21,800   19,230         88%        NaN      NaN      NaN
# 46      OKALOOSA        NaN      NaN         NaN        NaN      NaN      NaN
# 47    OKEECHOBEE     20,000   19,080         95%        NaN      NaN      NaN
# 48        ORANGE         10       10        100%    369,171  220,151      60%
# 49       OSCEOLA         10       10        100%     48,065   23,995      50%
# 50    PALM BEACH    739,000  481,020         65%        NaN      NaN      NaN
# 51         PASCO        NaN      NaN         NaN    139,992  102,846      73%
# 52      PINELLAS        NaN      NaN         NaN    540,933  430,984      80%
# 53          POLK        NaN      NaN         NaN    100,519   66,618      66%
# 54        PUTNAM     20,100   18,980         94%        NaN      NaN      NaN
# 55    SANTA ROSA        NaN      NaN         NaN        NaN      NaN      NaN
# 56      SARASOTA    263,800  152,500         58%        NaN      NaN      NaN
# 57      SEMINOLE     54,400   37,190         68%    156,103  116,594      75%
# 58     ST. JOHNS     86,800   71,790         83%        NaN      NaN      NaN
# 59     ST. LUCIE    126,200   88,040         70%        NaN      NaN      NaN
# 60        SUMTER        NaN      NaN         NaN     10,171    8,800      87%
# 61      SUWANNEE      5,100    4,530         89%        797      470      59%
# 62        TAYLOR        NaN      NaN         NaN      6,026    3,520      58%
# 63         UNION      1,700    1,220         72%        NaN      NaN      NaN
# 64       VOLUSIA    176,800  116,030         66%     81,055   68,078      84%
# 65       WAKULLA        NaN      NaN         NaN      6,814    3,876      57%
# 66        WALTON        NaN      NaN         NaN        NaN      NaN      NaN
# 67    WASHINGTON        NaN      NaN         NaN        NaN      NaN      NaN
#
#    gulf_total gulf_out gulf_pct       ...       coops_total coops_out  \
# 1         NaN      NaN      NaN       ...            23,226    19,983
# 2         NaN      NaN      NaN       ...             5,963     5,832
# 3     101,709      578       1%       ...            11,647       161
# 4         NaN      NaN      NaN       ...             5,864     4,587
# 5         NaN      NaN      NaN       ...             3,028       111
# 6         NaN      NaN      NaN       ...                54        54
# 7         NaN      NaN      NaN       ...             1,697       261
# 8         NaN      NaN      NaN       ...               858       858
# 9         NaN      NaN      NaN       ...            41,017    35,310
# 10        NaN      NaN      NaN       ...            80,056    45,638
# 11        NaN      NaN      NaN       ...            35,211    35,211
# 12        NaN      NaN      NaN       ...            18,797    16,411
# 13        NaN      NaN      NaN       ...               965       843
# 14        NaN      NaN      NaN       ...             8,217     5,704
# 15        NaN      NaN      NaN       ...                17        11
# 16    152,699       72       0%       ...             3,437         0
# 17        NaN      NaN      NaN       ...                 3         3
# 18        NaN      NaN      NaN       ...               NaN       NaN
# 19        NaN      NaN      NaN       ...            14,972     8,161
# 20        NaN      NaN      NaN       ...             7,263     5,571
# 21        NaN      NaN      NaN       ...             2,942     2,940
# 22        NaN      NaN      NaN       ...             4,439       565
# 23        NaN      NaN      NaN       ...             3,785     3,261
# 24        NaN      NaN      NaN       ...             6,846     5,857
# 25        NaN      NaN      NaN       ...             4,778     4,778
# 26        NaN      NaN      NaN       ...            83,599    50,280
# 27        NaN      NaN      NaN       ...             7,647     7,638
# 28        NaN      NaN      NaN       ...             1,148       928
# 29      2,581       63       2%       ...             7,842         9
# 30        NaN      NaN      NaN       ...               215       172
# ..        ...      ...      ...       ...               ...       ...
# 38        NaN      NaN      NaN       ...             3,289     1,196
# 39        NaN      NaN      NaN       ...             6,897     4,422
# 40        NaN      NaN      NaN       ...            24,857     6,343
# 41        NaN      NaN      NaN       ...            73,611    49,185
# 42        NaN      NaN      NaN       ...               NaN       NaN
# 43        NaN      NaN      NaN       ...               NaN       NaN
# 44        NaN      NaN      NaN       ...            32,500    21,666
# 45        NaN      NaN      NaN       ...             6,920     6,839
# 46     92,602      121       0%       ...            15,809         0
# 47        NaN      NaN      NaN       ...             2,790     2,790
# 48        NaN      NaN      NaN       ...               NaN       NaN
# 49        NaN      NaN      NaN       ...               914       746
# 50        NaN      NaN      NaN       ...               NaN       NaN
# 51        NaN      NaN      NaN       ...           106,267    71,990
# 52        NaN      NaN      NaN       ...               NaN       NaN
# 53        NaN      NaN      NaN       ...             5,797     5,410
# 54        NaN      NaN      NaN       ...            21,166    17,654
# 55     68,697        4       0%       ...             7,559         0
# 56        NaN      NaN      NaN       ...                35         0
# 57        NaN      NaN      NaN       ...               NaN       NaN
# 58        NaN      NaN      NaN       ...               NaN       NaN
# 59        NaN      NaN      NaN       ...               NaN       NaN
# 60        NaN      NaN      NaN       ...            61,939    18,298
# 61        NaN      NaN      NaN       ...            16,860    15,991
# 62        NaN      NaN      NaN       ...             6,890     5,429
# 63        NaN      NaN      NaN       ...             3,738     3,341
# 64        NaN      NaN      NaN       ...             2,151     1,928
# 65        NaN      NaN      NaN       ...             8,657     3,466
# 66     23,143        2       0%       ...            36,333        48
# 67      6,481      346       5%       ...             6,609       166
#
#    coops_pct muni_total muni_out muni_pct overall_out overall_total  \
# 1        86%    100,626   39,327      39%      63,246       130,032
# 2        98%        NaN      NaN      NaN      10,152        11,363
# 3         1%        NaN      NaN      NaN       1,991       115,629
# 4        78%      2,685    2,685     100%      11,222        12,649
# 5         4%        NaN      NaN      NaN     212,440       310,644
# 6       100%        NaN      NaN      NaN     601,424       933,354
# 7        15%      1,314      300      23%         816         3,936
# 8       100%        NaN      NaN      NaN      62,638       114,958
# 9        86%        NaN      NaN      NaN      69,269        87,714
# 10       57%     13,883    7,311      53%      53,409        94,839
# 11      100%        NaN      NaN      NaN     232,011       245,911
# 12       87%        NaN      NaN      NaN      30,347        33,363
# 13       87%        NaN      NaN      NaN      13,673        17,565
# 14       69%        NaN      NaN      NaN       6,770        10,017
# 15       65%    449,815  257,240      57%     257,261       449,842
# 16        0%        NaN      NaN      NaN          72       156,136
# 17      100%        NaN      NaN      NaN      46,816        58,019
# 18       NaN        NaN      NaN      NaN       5,824        10,202
# 19       55%      7,322      136       2%       8,297        22,294
# 20       77%        NaN      NaN      NaN       6,515         8,900
# 21      100%        912      912     100%       6,202         7,254
# 22       13%        NaN      NaN      NaN       4,198        10,909
# 23       86%        NaN      NaN      NaN       4,998         6,712
# 24       86%      2,734    2,734     100%      11,282        12,291
# 25      100%      4,272    4,272     100%      18,750        18,750
# 26       60%        NaN      NaN      NaN      58,644        94,940
# 27      100%        NaN      NaN      NaN      61,993        62,456
# 28       81%        NaN      NaN      NaN     264,737       632,953
# 29        0%        NaN      NaN      NaN          72        10,423
# 30       80%     35,030   13,203      38%      54,465        91,545
# ..       ...        ...      ...      ...         ...           ...
# 38       36%        NaN      NaN      NaN       1,197         4,058
# 39       64%        NaN      NaN      NaN       6,684        10,708
# 40       26%        NaN      NaN      NaN     110,923       209,757
# 41       67%     49,955   38,188      76%     142,002       189,091
# 42       NaN        NaN      NaN      NaN      63,200        93,400
# 43       NaN     23,086   18,748      81%     801,648     1,137,086
# 44       67%     31,183   31,183     100%      52,939        63,773
# 45       99%        NaN      NaN      NaN      41,360        44,796
# 46        0%        NaN      NaN      NaN         121       108,411
# 47      100%        NaN      NaN      NaN      21,870        22,790
# 48       NaN    211,091  117,000      55%     337,161       580,272
# 49       82%    103,742   30,601      29%      55,352       152,731
# 50       NaN     27,847   24,500      88%     505,520       766,847
# 51       68%        NaN      NaN      NaN     190,567       270,095
# 52       NaN        NaN      NaN      NaN     431,754       551,917
# 53       93%    139,134   77,539      56%     202,080       330,732
# 54       83%        NaN      NaN      NaN      36,634        41,266
# 55        0%        NaN      NaN      NaN           4        76,256
# 56        0%        NaN      NaN      NaN     152,500       263,835
# 57       NaN        NaN      NaN      NaN     153,784       210,503
# 58       NaN     43,969   24,480      56%      96,270       130,769
# 59       NaN     27,630   17,510      63%     105,550       153,830
# 60       30%      1,500    1,500     100%      28,598        73,610
# 61       95%        NaN      NaN      NaN      20,991        22,757
# 62       79%        NaN      NaN      NaN       8,949        12,916
# 63       89%        NaN      NaN      NaN       4,561         5,438
# 64       90%     26,539   26,539     100%     212,575       286,545
# 65       40%        NaN      NaN      NaN       7,342        15,471
# 66        0%        NaN      NaN      NaN          50        59,476
# 67        3%        NaN      NaN      NaN         512        13,090
#
#    overall_with_pct overall_out_pct
# 1               51%             49%
# 2               11%             89%
# 3               98%              2%
# 4               11%             89%
# 5               32%             68%
# 6               36%             64%
# 7               79%             21%
# 8               46%             54%
# 9               21%             79%
# 10              44%             56%
# 11               6%             94%
# 12               9%             91%
# 13              22%             78%
# 14              32%             68%
# 15              43%             57%
# 16             100%              0%
# 17              19%             81%
# 18              43%             57%
# 19              63%             37%
# 20              27%             73%
# 21              15%             85%
# 22              62%             38%
# 23              26%             74%
# 24               8%             92%
# 25               0%            100%
# 26              38%             62%
# 27               1%             99%
# 28              58%             42%
# 29              99%              1%
# 30              41%             59%
# ..              ...             ...
# 38              71%             29%
# 39              38%             62%
# 40              47%             53%
# 41              25%             75%
# 42              32%             68%
# 43              29%             71%
# 44              17%             83%
# 45               8%             92%
# 46             100%              0%
# 47               4%             96%
# 48              42%             58%
# 49              64%             36%
# 50              34%             66%
# 51              29%             71%
# 52              22%             78%
# 53              39%             61%
# 54              11%             89%
# 55             100%              0%
# 56              42%             58%
# 57              27%             73%
# 58              26%             74%
# 59              31%             69%
# 60              61%             39%
# 61               8%             92%
# 62              31%             69%
# 63              16%             84%
# 64              26%             74%
# 65              53%             47%
# 66             100%              0%
# 67              96%              4%
#
# [67 rows x 26 columns]

# %%
df_latestClean['county_name'] = df_latestClean['county_name'].apply(properCase)
df_latestClean
# Out:
#      county_name  fpl_total  fpl_out fpl_out_pct duke_total duke_out duke_pct  \
# 1        Alachua      1,300      860         66%      4,880    3,076      63%
# 2          Baker      5,400    4,320         80%        NaN      NaN      NaN
# 3            Bay        NaN      NaN         NaN      2,273    1,252      55%
# 4       Bradford      4,100    3,950         96%        NaN      NaN      NaN
# 5        Brevard    307,600  212,320         69%         16        9      56%
# 6        Broward    933,300  601,370         64%        NaN      NaN      NaN
# 7        Calhoun        NaN      NaN         NaN        NaN      NaN      NaN
# 8      Charlotte    114,100   61,780         54%        NaN      NaN      NaN
# 9         Citrus        NaN      NaN         NaN     46,697   33,959      73%
# 10          Clay        900      460         51%        NaN      NaN      NaN
# 11       Collier    210,700  196,800         93%        NaN      NaN      NaN
# 12      Columbia     14,000   13,610         97%        566      326      58%
# 13        DeSoto     16,600   12,830         77%        NaN      NaN      NaN
# 14         Dixie        NaN      NaN         NaN      1,800    1,066      59%
# 15         Duval         10       10        100%        NaN      NaN      NaN
# 16      Escambia        NaN      NaN         NaN        NaN      NaN      NaN
# 17       Flagler     58,000   46,800         81%         16       13      81%
# 18      Franklin        NaN      NaN         NaN     10,202    5,824      57%
# 19       Gadsden        NaN      NaN         NaN        NaN      NaN      NaN
# 20     Gilchrist        NaN      NaN         NaN      1,637      944      58%
# 21        Glades      3,400    2,350         69%        NaN      NaN      NaN
# 22          Gulf        NaN      NaN         NaN      6,470    3,633      56%
# 23      Hamilton        NaN      NaN         NaN      2,927    1,737      59%
# 24        Hardee         40       30         75%      2,671    2,661     100%
# 25        Hendry      9,700    9,700        100%        NaN      NaN      NaN
# 26      Hernando        NaN      NaN         NaN     11,341    8,364      74%
# 27     Highlands        600      490         82%     54,209   53,865      99%
# 28  Hillsborough        NaN      NaN         NaN         25       19      76%
# 29        Holmes        NaN      NaN         NaN        NaN      NaN      NaN
# 30  Indian River     56,300   41,090         73%        NaN      NaN      NaN
# ..           ...        ...      ...         ...        ...      ...      ...
# 38       Liberty        NaN      NaN         NaN        NaN      NaN      NaN
# 39       Madison        NaN      NaN         NaN      3,811    2,262      59%
# 40       Manatee    184,900  104,580         57%        NaN      NaN      NaN
# 41        Marion        NaN      NaN         NaN     65,525   54,629      83%
# 42        Martin     93,400   63,200         68%        NaN      NaN      NaN
# 43    Miami-Dade  1,114,000  782,900         70%        NaN      NaN      NaN
# 44        Monroe         90       90        100%        NaN      NaN      NaN
# 45        Nassau     21,800   19,230         88%        NaN      NaN      NaN
# 46      Okaloosa        NaN      NaN         NaN        NaN      NaN      NaN
# 47    Okeechobee     20,000   19,080         95%        NaN      NaN      NaN
# 48        Orange         10       10        100%    369,171  220,151      60%
# 49       Osceola         10       10        100%     48,065   23,995      50%
# 50    Palm Beach    739,000  481,020         65%        NaN      NaN      NaN
# 51         Pasco        NaN      NaN         NaN    139,992  102,846      73%
# 52      Pinellas        NaN      NaN         NaN    540,933  430,984      80%
# 53          Polk        NaN      NaN         NaN    100,519   66,618      66%
# 54        Putnam     20,100   18,980         94%        NaN      NaN      NaN
# 55    Santa Rosa        NaN      NaN         NaN        NaN      NaN      NaN
# 56      Sarasota    263,800  152,500         58%        NaN      NaN      NaN
# 57      Seminole     54,400   37,190         68%    156,103  116,594      75%
# 58     St. Johns     86,800   71,790         83%        NaN      NaN      NaN
# 59     St. Lucie    126,200   88,040         70%        NaN      NaN      NaN
# 60        Sumter        NaN      NaN         NaN     10,171    8,800      87%
# 61      Suwannee      5,100    4,530         89%        797      470      59%
# 62        Taylor        NaN      NaN         NaN      6,026    3,520      58%
# 63         Union      1,700    1,220         72%        NaN      NaN      NaN
# 64       Volusia    176,800  116,030         66%     81,055   68,078      84%
# 65       Wakulla        NaN      NaN         NaN      6,814    3,876      57%
# 66        Walton        NaN      NaN         NaN        NaN      NaN      NaN
# 67    Washington        NaN      NaN         NaN        NaN      NaN      NaN
#
#    gulf_total gulf_out gulf_pct       ...       coops_total coops_out  \
# 1         NaN      NaN      NaN       ...            23,226    19,983
# 2         NaN      NaN      NaN       ...             5,963     5,832
# 3     101,709      578       1%       ...            11,647       161
# 4         NaN      NaN      NaN       ...             5,864     4,587
# 5         NaN      NaN      NaN       ...             3,028       111
# 6         NaN      NaN      NaN       ...                54        54
# 7         NaN      NaN      NaN       ...             1,697       261
# 8         NaN      NaN      NaN       ...               858       858
# 9         NaN      NaN      NaN       ...            41,017    35,310
# 10        NaN      NaN      NaN       ...            80,056    45,638
# 11        NaN      NaN      NaN       ...            35,211    35,211
# 12        NaN      NaN      NaN       ...            18,797    16,411
# 13        NaN      NaN      NaN       ...               965       843
# 14        NaN      NaN      NaN       ...             8,217     5,704
# 15        NaN      NaN      NaN       ...                17        11
# 16    152,699       72       0%       ...             3,437         0
# 17        NaN      NaN      NaN       ...                 3         3
# 18        NaN      NaN      NaN       ...               NaN       NaN
# 19        NaN      NaN      NaN       ...            14,972     8,161
# 20        NaN      NaN      NaN       ...             7,263     5,571
# 21        NaN      NaN      NaN       ...             2,942     2,940
# 22        NaN      NaN      NaN       ...             4,439       565
# 23        NaN      NaN      NaN       ...             3,785     3,261
# 24        NaN      NaN      NaN       ...             6,846     5,857
# 25        NaN      NaN      NaN       ...             4,778     4,778
# 26        NaN      NaN      NaN       ...            83,599    50,280
# 27        NaN      NaN      NaN       ...             7,647     7,638
# 28        NaN      NaN      NaN       ...             1,148       928
# 29      2,581       63       2%       ...             7,842         9
# 30        NaN      NaN      NaN       ...               215       172
# ..        ...      ...      ...       ...               ...       ...
# 38        NaN      NaN      NaN       ...             3,289     1,196
# 39        NaN      NaN      NaN       ...             6,897     4,422
# 40        NaN      NaN      NaN       ...            24,857     6,343
# 41        NaN      NaN      NaN       ...            73,611    49,185
# 42        NaN      NaN      NaN       ...               NaN       NaN
# 43        NaN      NaN      NaN       ...               NaN       NaN
# 44        NaN      NaN      NaN       ...            32,500    21,666
# 45        NaN      NaN      NaN       ...             6,920     6,839
# 46     92,602      121       0%       ...            15,809         0
# 47        NaN      NaN      NaN       ...             2,790     2,790
# 48        NaN      NaN      NaN       ...               NaN       NaN
# 49        NaN      NaN      NaN       ...               914       746
# 50        NaN      NaN      NaN       ...               NaN       NaN
# 51        NaN      NaN      NaN       ...           106,267    71,990
# 52        NaN      NaN      NaN       ...               NaN       NaN
# 53        NaN      NaN      NaN       ...             5,797     5,410
# 54        NaN      NaN      NaN       ...            21,166    17,654
# 55     68,697        4       0%       ...             7,559         0
# 56        NaN      NaN      NaN       ...                35         0
# 57        NaN      NaN      NaN       ...               NaN       NaN
# 58        NaN      NaN      NaN       ...               NaN       NaN
# 59        NaN      NaN      NaN       ...               NaN       NaN
# 60        NaN      NaN      NaN       ...            61,939    18,298
# 61        NaN      NaN      NaN       ...            16,860    15,991
# 62        NaN      NaN      NaN       ...             6,890     5,429
# 63        NaN      NaN      NaN       ...             3,738     3,341
# 64        NaN      NaN      NaN       ...             2,151     1,928
# 65        NaN      NaN      NaN       ...             8,657     3,466
# 66     23,143        2       0%       ...            36,333        48
# 67      6,481      346       5%       ...             6,609       166
#
#    coops_pct muni_total muni_out muni_pct overall_out overall_total  \
# 1        86%    100,626   39,327      39%      63,246       130,032
# 2        98%        NaN      NaN      NaN      10,152        11,363
# 3         1%        NaN      NaN      NaN       1,991       115,629
# 4        78%      2,685    2,685     100%      11,222        12,649
# 5         4%        NaN      NaN      NaN     212,440       310,644
# 6       100%        NaN      NaN      NaN     601,424       933,354
# 7        15%      1,314      300      23%         816         3,936
# 8       100%        NaN      NaN      NaN      62,638       114,958
# 9        86%        NaN      NaN      NaN      69,269        87,714
# 10       57%     13,883    7,311      53%      53,409        94,839
# 11      100%        NaN      NaN      NaN     232,011       245,911
# 12       87%        NaN      NaN      NaN      30,347        33,363
# 13       87%        NaN      NaN      NaN      13,673        17,565
# 14       69%        NaN      NaN      NaN       6,770        10,017
# 15       65%    449,815  257,240      57%     257,261       449,842
# 16        0%        NaN      NaN      NaN          72       156,136
# 17      100%        NaN      NaN      NaN      46,816        58,019
# 18       NaN        NaN      NaN      NaN       5,824        10,202
# 19       55%      7,322      136       2%       8,297        22,294
# 20       77%        NaN      NaN      NaN       6,515         8,900
# 21      100%        912      912     100%       6,202         7,254
# 22       13%        NaN      NaN      NaN       4,198        10,909
# 23       86%        NaN      NaN      NaN       4,998         6,712
# 24       86%      2,734    2,734     100%      11,282        12,291
# 25      100%      4,272    4,272     100%      18,750        18,750
# 26       60%        NaN      NaN      NaN      58,644        94,940
# 27      100%        NaN      NaN      NaN      61,993        62,456
# 28       81%        NaN      NaN      NaN     264,737       632,953
# 29        0%        NaN      NaN      NaN          72        10,423
# 30       80%     35,030   13,203      38%      54,465        91,545
# ..       ...        ...      ...      ...         ...           ...
# 38       36%        NaN      NaN      NaN       1,197         4,058
# 39       64%        NaN      NaN      NaN       6,684        10,708
# 40       26%        NaN      NaN      NaN     110,923       209,757
# 41       67%     49,955   38,188      76%     142,002       189,091
# 42       NaN        NaN      NaN      NaN      63,200        93,400
# 43       NaN     23,086   18,748      81%     801,648     1,137,086
# 44       67%     31,183   31,183     100%      52,939        63,773
# 45       99%        NaN      NaN      NaN      41,360        44,796
# 46        0%        NaN      NaN      NaN         121       108,411
# 47      100%        NaN      NaN      NaN      21,870        22,790
# 48       NaN    211,091  117,000      55%     337,161       580,272
# 49       82%    103,742   30,601      29%      55,352       152,731
# 50       NaN     27,847   24,500      88%     505,520       766,847
# 51       68%        NaN      NaN      NaN     190,567       270,095
# 52       NaN        NaN      NaN      NaN     431,754       551,917
# 53       93%    139,134   77,539      56%     202,080       330,732
# 54       83%        NaN      NaN      NaN      36,634        41,266
# 55        0%        NaN      NaN      NaN           4        76,256
# 56        0%        NaN      NaN      NaN     152,500       263,835
# 57       NaN        NaN      NaN      NaN     153,784       210,503
# 58       NaN     43,969   24,480      56%      96,270       130,769
# 59       NaN     27,630   17,510      63%     105,550       153,830
# 60       30%      1,500    1,500     100%      28,598        73,610
# 61       95%        NaN      NaN      NaN      20,991        22,757
# 62       79%        NaN      NaN      NaN       8,949        12,916
# 63       89%        NaN      NaN      NaN       4,561         5,438
# 64       90%     26,539   26,539     100%     212,575       286,545
# 65       40%        NaN      NaN      NaN       7,342        15,471
# 66        0%        NaN      NaN      NaN          50        59,476
# 67        3%        NaN      NaN      NaN         512        13,090
#
#    overall_with_pct overall_out_pct
# 1               51%             49%
# 2               11%             89%
# 3               98%              2%
# 4               11%             89%
# 5               32%             68%
# 6               36%             64%
# 7               79%             21%
# 8               46%             54%
# 9               21%             79%
# 10              44%             56%
# 11               6%             94%
# 12               9%             91%
# 13              22%             78%
# 14              32%             68%
# 15              43%             57%
# 16             100%              0%
# 17              19%             81%
# 18              43%             57%
# 19              63%             37%
# 20              27%             73%
# 21              15%             85%
# 22              62%             38%
# 23              26%             74%
# 24               8%             92%
# 25               0%            100%
# 26              38%             62%
# 27               1%             99%
# 28              58%             42%
# 29              99%              1%
# 30              41%             59%
# ..              ...             ...
# 38              71%             29%
# 39              38%             62%
# 40              47%             53%
# 41              25%             75%
# 42              32%             68%
# 43              29%             71%
# 44              17%             83%
# 45               8%             92%
# 46             100%              0%
# 47               4%             96%
# 48              42%             58%
# 49              64%             36%
# 50              34%             66%
# 51              29%             71%
# 52              22%             78%
# 53              39%             61%
# 54              11%             89%
# 55             100%              0%
# 56              42%             58%
# 57              27%             73%
# 58              26%             74%
# 59              31%             69%
# 60              61%             39%
# 61               8%             92%
# 62              31%             69%
# 63              16%             84%
# 64              26%             74%
# 65              53%             47%
# 66             100%              0%
# 67              96%              4%
#
# [67 rows x 26 columns]

# %%
df_dataMerge = df_fips.merge(df_latestClean,on='county_name',how='outer')
df_dataMerge = df_dataMerge.rename(columns={'fips_code':'county_fips'})
df_dataMerge
df_dataMerge.to_csv('data/finalData.csv')
