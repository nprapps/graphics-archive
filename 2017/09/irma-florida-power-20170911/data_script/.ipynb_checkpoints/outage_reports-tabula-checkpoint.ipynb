# %%
# -*- coding: utf-8 -*-
# %matplotlib inline

import pandas as pd
import numpy as np
import math
import matplotlib as mplstyle
import matplotlib.pyplot as plt
import locale
import arrow
from locale import atof
from dateutil import parser
from datetime import datetime

# %%
def countyFips(countyCode):
    if (countyCode < 10):
        return '1200' + str(countyCode)
    if (countyCode < 100):
        return '120' + str(countyCode)
    if (countyCode > 100):
        return '12' + str(countyCode)

def removeWord(county):
    return county.replace(' County', '')

def properCase(county):
    if (county == 'DESOTO'):
        return 'DeSoto'
    else:
        return county.title()

# %%
# import data
df_fips_original = pd.read_csv('data/fips.csv')
df_latest = pd.read_csv('data/outage-reports-091117-4pm.csv', header=None)

# %%
df_latest
# Out:
#               0          1        2     3        4        5     6        7   \
# 0        ALACHUA      1,300    1,300  100%    4,880    3,056   63%      NaN
# 1          BAKER      5,400    4,460   83%      NaN      NaN   NaN      NaN
# 2            BAY        NaN      NaN   NaN    2,273    1,241   55%  101,709
# 3       BRADFORD      4,100    3,870   94%      NaN      NaN   NaN      NaN
# 4        BREVARD    307,600  225,490   73%       16        9   56%      NaN
# 5        BROWARD    933,300  629,080   67%      NaN      NaN   NaN      NaN
# 6        CALHOUN        NaN      NaN   NaN      NaN      NaN   NaN      NaN
# 7      CHARLOTTE    114,100   65,870   58%      NaN      NaN   NaN      NaN
# 8         CITRUS        NaN      NaN   NaN   46,697   33,755   72%      NaN
# 9           CLAY        900      900  100%      NaN      NaN   NaN      NaN
# 10       COLLIER    210,700  200,930   95%      NaN      NaN   NaN      NaN
# 11      COLUMBIA     14,000   14,000  100%      566      323   57%      NaN
# 12        DESOTO     16,600   13,960   84%      NaN      NaN   NaN      NaN
# 13         DIXIE        NaN      NaN   NaN    1,800    1,057   59%      NaN
# 14         DUVAL         10       10  100%      NaN      NaN   NaN      NaN
# 15      ESCAMBIA        NaN      NaN   NaN      NaN      NaN   NaN  152,699
# 16       FLAGLER     58,000   49,640   86%       16       13   81%      NaN
# 17      FRANKLIN        NaN      NaN   NaN   10,202    5,775   57%      NaN
# 18       GADSDEN        NaN      NaN   NaN      NaN      NaN   NaN      NaN
# 19     GILCHRIST        NaN      NaN   NaN    1,637      936   57%      NaN
# 20        GLADES      3,400    2,420   71%      NaN      NaN   NaN      NaN
# 21          GULF        NaN      NaN   NaN    6,470    3,602   56%      NaN
# 22      HAMILTON        NaN      NaN   NaN    2,927    1,723   59%      NaN
# 23        HARDEE         40       30   75%    2,671    2,671  100%      NaN
# 24        HENDRY      9,700    9,700  100%      NaN      NaN   NaN      NaN
# 25      HERNANDO        NaN      NaN   NaN   11,341    7,618   67%      NaN
# 26     HIGHLANDS        600      420   70%   54,209   53,952  100%      NaN
# 27  HILLSBOROUGH        NaN      NaN   NaN       25       19   76%      NaN
# 28        HOLMES        NaN      NaN   NaN      NaN      NaN   NaN    2,581
# 29  INDIAN RIVER     56,300   42,240   75%      NaN      NaN   NaN      NaN
# ..           ...        ...      ...   ...      ...      ...   ...      ...
# 37       LIBERTY        NaN      NaN   NaN      NaN      NaN   NaN      NaN
# 38       MADISON        NaN      NaN   NaN    3,811    2,243   59%      NaN
# 39       MANATEE    184,900  106,620   58%      NaN      NaN   NaN      NaN
# 40        MARION        NaN      NaN   NaN   65,525   54,513   83%      NaN
# 41        MARTIN     93,400   69,870   75%      NaN      NaN   NaN      NaN
# 42    MIAMI-DADE  1,114,000  802,430   72%      NaN      NaN   NaN      NaN
# 43        MONROE         90       90  100%      NaN      NaN   NaN      NaN
# 44        NASSAU     21,800   20,820   96%      NaN      NaN   NaN      NaN
# 45      OKALOOSA        NaN      NaN   NaN      NaN      NaN   NaN   92,602
# 46    OKEECHOBEE     20,000   19,200   96%      NaN      NaN   NaN      NaN
# 47        ORANGE         10       10  100%  369,171  226,228   61%      NaN
# 48       OSCEOLA         10       10  100%   48,065   23,979   50%      NaN
# 49    PALM BEACH    739,000  509,490   69%      NaN      NaN   NaN      NaN
# 50         PASCO        NaN      NaN   NaN  139,992  102,846   73%      NaN
# 51      PINELLAS        NaN      NaN   NaN  540,933  428,475   79%      NaN
# 52          POLK        NaN      NaN   NaN  100,519   66,469   66%      NaN
# 53        PUTNAM     20,100   18,920   94%      NaN      NaN   NaN      NaN
# 54    SANTA ROSA        NaN      NaN   NaN      NaN      NaN   NaN   68,697
# 55      SARASOTA    263,800  170,120   64%      NaN      NaN   NaN      NaN
# 56      SEMINOLE     54,400   41,650   77%  156,103  116,255   74%      NaN
# 57     ST. JOHNS     86,800   75,930   87%      NaN      NaN   NaN      NaN
# 58     ST. LUCIE    126,200   92,990   74%      NaN      NaN   NaN      NaN
# 59        SUMTER        NaN      NaN   NaN   10,171    8,789   86%      NaN
# 60      SUWANNEE      5,100    4,530   89%      797      466   58%      NaN
# 61        TAYLOR        NaN      NaN   NaN    6,026    3,491   58%      NaN
# 62         UNION      1,700    1,150   68%      NaN      NaN   NaN      NaN
# 63       VOLUSIA    176,800  125,730   71%   81,055   68,131   84%      NaN
# 64       WAKULLA        NaN      NaN   NaN    6,814    3,844   56%      NaN
# 65        WALTON        NaN      NaN   NaN      NaN      NaN   NaN   23,143
# 66    WASHINGTON        NaN      NaN   NaN      NaN      NaN   NaN    6,481
#
#        8    9   ...        16      17    18       19       20    21       22  \
# 0     NaN  NaN  ...    23,226  19,957   86%  100,626   42,321   42%   66,634
# 1     NaN  NaN  ...     5,963   5,832   98%      NaN      NaN   NaN   10,292
# 2   101.0   0%  ...    11,647     161    1%      NaN      NaN   NaN    1,503
# 3     NaN  NaN  ...     5,864   4,472   76%    2,685    2,685  100%   11,027
# 4     NaN  NaN  ...     3,028     127    4%      NaN      NaN   NaN  225,626
# 5     NaN  NaN  ...        54      54  100%      NaN      NaN   NaN  629,134
# 6     NaN  NaN  ...     1,697     262   15%    1,314      300   23%      816
# 7     NaN  NaN  ...       858     840   98%      NaN      NaN   NaN   66,710
# 8     NaN  NaN  ...    41,017  35,310   86%      NaN      NaN   NaN   69,065
# 9     NaN  NaN  ...    80,056  52,778   66%   13,883    6,042   44%   59,720
# 10    NaN  NaN  ...    35,211  35,211  100%      NaN      NaN   NaN  236,141
# 11    NaN  NaN  ...    18,797  16,411   87%      NaN      NaN   NaN   30,734
# 12    NaN  NaN  ...       965     842   87%      NaN      NaN   NaN   14,802
# 13    NaN  NaN  ...     8,217   5,733   70%      NaN      NaN   NaN    6,790
# 14    NaN  NaN  ...        17      17  100%  449,815  252,591   56%  252,618
# 15   78.0   0%  ...     3,437       0    0%      NaN      NaN   NaN       78
# 16    NaN  NaN  ...         3       3  100%      NaN      NaN   NaN   49,656
# 17    NaN  NaN  ...       NaN     NaN   NaN      NaN      NaN   NaN    5,775
# 18    NaN  NaN  ...    14,972   8,654   58%    7,322      136    2%    8,790
# 19    NaN  NaN  ...     7,263   5,678   78%      NaN      NaN   NaN    6,614
# 20    NaN  NaN  ...     2,942   2,940  100%      912      912  100%    6,272
# 21    NaN  NaN  ...     4,439     835   19%      NaN      NaN   NaN    4,437
# 22    NaN  NaN  ...     3,785   3,125   83%      NaN      NaN   NaN    4,848
# 23    NaN  NaN  ...     6,846   5,840   85%    2,734    2,734  100%   11,275
# 24    NaN  NaN  ...     4,778   4,778  100%    4,272    4,272  100%   18,750
# 25    NaN  NaN  ...    83,599  50,280   60%      NaN      NaN   NaN   57,898
# 26    NaN  NaN  ...     7,647   7,638  100%      NaN      NaN   NaN   62,010
# 27    NaN  NaN  ...     1,148     684   60%      NaN      NaN   NaN  263,209
# 28    1.0   0%  ...     7,842      57    1%      NaN      NaN   NaN       58
# 29    NaN  NaN  ...       215     172   80%   35,030   25,790   74%   68,202
# ..    ...  ...  ...       ...     ...   ...      ...      ...   ...      ...
# 37    NaN  NaN  ...     3,289   1,470   45%      NaN      NaN   NaN    1,471
# 38    NaN  NaN  ...     6,897   4,647   67%      NaN      NaN   NaN    6,890
# 39    NaN  NaN  ...    24,857   6,245   25%      NaN      NaN   NaN  112,865
# 40    NaN  NaN  ...    73,611  49,184   67%   49,955   40,742   82%  144,439
# 41    NaN  NaN  ...       NaN     NaN   NaN      NaN      NaN   NaN   69,870
# 42    NaN  NaN  ...       NaN     NaN   NaN   23,086   21,000   91%  823,430
# 43    NaN  NaN  ...    32,500  21,666   67%   31,183   31,183  100%   52,939
# 44    NaN  NaN  ...     6,920   6,839   99%      NaN      NaN   NaN   43,735
# 45  110.0   0%  ...    15,809       0    0%      NaN      NaN   NaN      110
# 46    NaN  NaN  ...     2,790   2,790  100%      NaN      NaN   NaN   21,990
# 47    NaN  NaN  ...       NaN     NaN   NaN  211,091  130,143   62%  356,381
# 48    NaN  NaN  ...       914     746   82%  103,742   40,267   39%   65,002
# 49    NaN  NaN  ...       NaN     NaN   NaN   27,847   24,500   88%  533,990
# 50    NaN  NaN  ...   106,267  71,990   68%      NaN      NaN   NaN  189,194
# 51    NaN  NaN  ...       NaN     NaN   NaN      NaN      NaN   NaN  429,202
# 52    NaN  NaN  ...     5,797   5,410   93%  139,134   84,695   61%  207,236
# 53    NaN  NaN  ...    21,166  17,648   83%      NaN      NaN   NaN   36,568
# 54    2.0   0%  ...     7,559       0    0%      NaN      NaN   NaN        2
# 55    NaN  NaN  ...        35       0    0%      NaN      NaN   NaN  170,120
# 56    NaN  NaN  ...       NaN     NaN   NaN      NaN      NaN   NaN  157,905
# 57    NaN  NaN  ...       NaN     NaN   NaN   43,969   31,200   71%  107,130
# 58    NaN  NaN  ...       NaN     NaN   NaN   27,630   15,966   58%  108,956
# 59    NaN  NaN  ...    61,939  18,298   30%    1,500    1,500  100%   28,587
# 60    NaN  NaN  ...    16,860  15,979   95%      NaN      NaN   NaN   20,975
# 61    NaN  NaN  ...     6,890   5,509   80%      NaN      NaN   NaN    9,000
# 62    NaN  NaN  ...     3,738   3,485   93%      NaN      NaN   NaN    4,635
# 63    NaN  NaN  ...     2,151   1,928   90%   26,539   26,539  100%  222,328
# 64    NaN  NaN  ...     8,657   3,405   39%      NaN      NaN   NaN    7,249
# 65    4.0   0%  ...    36,333      48    0%      NaN      NaN   NaN       52
# 66  232.0   4%  ...     6,609   1,014   15%      NaN      NaN   NaN    1,246
#
#            23    24    25
# 0     130,032   49%   51%
# 1      11,363    9%   91%
# 2     115,629   99%    1%
# 3      12,649   13%   87%
# 4     310,644   27%   73%
# 5     933,354   33%   67%
# 6       3,936   79%   21%
# 7     114,958   42%   58%
# 8      87,714   21%   79%
# 9      94,839   37%   63%
# 10    245,911    4%   96%
# 11     33,363    8%   92%
# 12     17,565   16%   84%
# 13     10,017   32%   68%
# 14    449,842   44%   56%
# 15    156,136  100%    0%
# 16     58,019   14%   86%
# 17     10,202   43%   57%
# 18     22,294   61%   39%
# 19      8,900   26%   74%
# 20      7,254   14%   86%
# 21     10,909   59%   41%
# 22      6,712   28%   72%
# 23     12,291    8%   92%
# 24     18,750    0%  100%
# 25     94,940   39%   61%
# 26     62,456    1%   99%
# 27    632,953   58%   42%
# 28     10,423   99%    1%
# 29     91,545   25%   75%
# ..        ...   ...   ...
# 37      4,058   64%   36%
# 38     10,708   36%   64%
# 39    209,757   46%   54%
# 40    189,091   24%   76%
# 41     93,400   25%   75%
# 42  1,137,086   28%   72%
# 43     63,773   17%   83%
# 44     44,796    2%   98%
# 45    108,411  100%    0%
# 46     22,790    4%   96%
# 47    580,272   39%   61%
# 48    152,731   57%   43%
# 49    766,847   30%   70%
# 50    270,095   30%   70%
# 51    551,917   22%   78%
# 52    330,732   37%   63%
# 53     41,266   11%   89%
# 54     76,256  100%    0%
# 55    263,835   36%   64%
# 56    210,503   25%   75%
# 57    130,769   18%   82%
# 58    153,830   29%   71%
# 59     73,610   61%   39%
# 60     22,757    8%   92%
# 61     12,916   30%   70%
# 62      5,438   15%   85%
# 63    286,545   22%   78%
# 64     15,471   53%   47%
# 65     59,476  100%    0%
# 66     13,090   90%   10%
#
# [67 rows x 26 columns]

# %%
# duplicate fips dataframe and build full fips codes with state + county num then drop unnecessary columns + reorder
df_fips = df_fips_original
df_fips['fips_code'] = df_fips_original['county_code'].apply(countyFips)
df_fips = df_fips.drop(['state','state_code','county_code','Unnamed: 4'], axis=1)

cols = ['fips_code','county_name']
df_fips = df_fips[cols]
df_fips['county_name'] = df_fips['county_name'].apply(removeWord)
# df_fips

# %%
# df_latest = df_latest.drop([0,1])
# df_latest.columns = df_latest.iloc[0]
# df_latestClean = df_latest.reset_index().drop([0])
# df_latestClean = df_latestClean.drop(['index'], axis=1)

# %%
df_latestClean = df_latest
list(df_latestClean)
df_latestClean.columns = ['county_name','fpl_total','fpl_out','fpl_out_pct','duke_total','duke_out','duke_pct','gulf_total','gulf_out','gulf_pct','tampa_total','tampa_out','tampa_pct','fpu_total','fpu_out','fpu_pct','coops_total','coops_out','coops_pct','muni_total','muni_out','muni_pct','overall_out','overall_total','overall_with_pct','overall_out_pct'
]
df_latestClean
# Out:
#      county_name  fpl_total  fpl_out fpl_out_pct duke_total duke_out duke_pct  \
# 0        ALACHUA      1,300    1,300        100%      4,880    3,056      63%
# 1          BAKER      5,400    4,460         83%        NaN      NaN      NaN
# 2            BAY        NaN      NaN         NaN      2,273    1,241      55%
# 3       BRADFORD      4,100    3,870         94%        NaN      NaN      NaN
# 4        BREVARD    307,600  225,490         73%         16        9      56%
# 5        BROWARD    933,300  629,080         67%        NaN      NaN      NaN
# 6        CALHOUN        NaN      NaN         NaN        NaN      NaN      NaN
# 7      CHARLOTTE    114,100   65,870         58%        NaN      NaN      NaN
# 8         CITRUS        NaN      NaN         NaN     46,697   33,755      72%
# 9           CLAY        900      900        100%        NaN      NaN      NaN
# 10       COLLIER    210,700  200,930         95%        NaN      NaN      NaN
# 11      COLUMBIA     14,000   14,000        100%        566      323      57%
# 12        DESOTO     16,600   13,960         84%        NaN      NaN      NaN
# 13         DIXIE        NaN      NaN         NaN      1,800    1,057      59%
# 14         DUVAL         10       10        100%        NaN      NaN      NaN
# 15      ESCAMBIA        NaN      NaN         NaN        NaN      NaN      NaN
# 16       FLAGLER     58,000   49,640         86%         16       13      81%
# 17      FRANKLIN        NaN      NaN         NaN     10,202    5,775      57%
# 18       GADSDEN        NaN      NaN         NaN        NaN      NaN      NaN
# 19     GILCHRIST        NaN      NaN         NaN      1,637      936      57%
# 20        GLADES      3,400    2,420         71%        NaN      NaN      NaN
# 21          GULF        NaN      NaN         NaN      6,470    3,602      56%
# 22      HAMILTON        NaN      NaN         NaN      2,927    1,723      59%
# 23        HARDEE         40       30         75%      2,671    2,671     100%
# 24        HENDRY      9,700    9,700        100%        NaN      NaN      NaN
# 25      HERNANDO        NaN      NaN         NaN     11,341    7,618      67%
# 26     HIGHLANDS        600      420         70%     54,209   53,952     100%
# 27  HILLSBOROUGH        NaN      NaN         NaN         25       19      76%
# 28        HOLMES        NaN      NaN         NaN        NaN      NaN      NaN
# 29  INDIAN RIVER     56,300   42,240         75%        NaN      NaN      NaN
# ..           ...        ...      ...         ...        ...      ...      ...
# 37       LIBERTY        NaN      NaN         NaN        NaN      NaN      NaN
# 38       MADISON        NaN      NaN         NaN      3,811    2,243      59%
# 39       MANATEE    184,900  106,620         58%        NaN      NaN      NaN
# 40        MARION        NaN      NaN         NaN     65,525   54,513      83%
# 41        MARTIN     93,400   69,870         75%        NaN      NaN      NaN
# 42    MIAMI-DADE  1,114,000  802,430         72%        NaN      NaN      NaN
# 43        MONROE         90       90        100%        NaN      NaN      NaN
# 44        NASSAU     21,800   20,820         96%        NaN      NaN      NaN
# 45      OKALOOSA        NaN      NaN         NaN        NaN      NaN      NaN
# 46    OKEECHOBEE     20,000   19,200         96%        NaN      NaN      NaN
# 47        ORANGE         10       10        100%    369,171  226,228      61%
# 48       OSCEOLA         10       10        100%     48,065   23,979      50%
# 49    PALM BEACH    739,000  509,490         69%        NaN      NaN      NaN
# 50         PASCO        NaN      NaN         NaN    139,992  102,846      73%
# 51      PINELLAS        NaN      NaN         NaN    540,933  428,475      79%
# 52          POLK        NaN      NaN         NaN    100,519   66,469      66%
# 53        PUTNAM     20,100   18,920         94%        NaN      NaN      NaN
# 54    SANTA ROSA        NaN      NaN         NaN        NaN      NaN      NaN
# 55      SARASOTA    263,800  170,120         64%        NaN      NaN      NaN
# 56      SEMINOLE     54,400   41,650         77%    156,103  116,255      74%
# 57     ST. JOHNS     86,800   75,930         87%        NaN      NaN      NaN
# 58     ST. LUCIE    126,200   92,990         74%        NaN      NaN      NaN
# 59        SUMTER        NaN      NaN         NaN     10,171    8,789      86%
# 60      SUWANNEE      5,100    4,530         89%        797      466      58%
# 61        TAYLOR        NaN      NaN         NaN      6,026    3,491      58%
# 62         UNION      1,700    1,150         68%        NaN      NaN      NaN
# 63       VOLUSIA    176,800  125,730         71%     81,055   68,131      84%
# 64       WAKULLA        NaN      NaN         NaN      6,814    3,844      56%
# 65        WALTON        NaN      NaN         NaN        NaN      NaN      NaN
# 66    WASHINGTON        NaN      NaN         NaN        NaN      NaN      NaN
#
#    gulf_total  gulf_out gulf_pct       ...       coops_total coops_out  \
# 0         NaN       NaN      NaN       ...            23,226    19,957
# 1         NaN       NaN      NaN       ...             5,963     5,832
# 2     101,709     101.0       0%       ...            11,647       161
# 3         NaN       NaN      NaN       ...             5,864     4,472
# 4         NaN       NaN      NaN       ...             3,028       127
# 5         NaN       NaN      NaN       ...                54        54
# 6         NaN       NaN      NaN       ...             1,697       262
# 7         NaN       NaN      NaN       ...               858       840
# 8         NaN       NaN      NaN       ...            41,017    35,310
# 9         NaN       NaN      NaN       ...            80,056    52,778
# 10        NaN       NaN      NaN       ...            35,211    35,211
# 11        NaN       NaN      NaN       ...            18,797    16,411
# 12        NaN       NaN      NaN       ...               965       842
# 13        NaN       NaN      NaN       ...             8,217     5,733
# 14        NaN       NaN      NaN       ...                17        17
# 15    152,699      78.0       0%       ...             3,437         0
# 16        NaN       NaN      NaN       ...                 3         3
# 17        NaN       NaN      NaN       ...               NaN       NaN
# 18        NaN       NaN      NaN       ...            14,972     8,654
# 19        NaN       NaN      NaN       ...             7,263     5,678
# 20        NaN       NaN      NaN       ...             2,942     2,940
# 21        NaN       NaN      NaN       ...             4,439       835
# 22        NaN       NaN      NaN       ...             3,785     3,125
# 23        NaN       NaN      NaN       ...             6,846     5,840
# 24        NaN       NaN      NaN       ...             4,778     4,778
# 25        NaN       NaN      NaN       ...            83,599    50,280
# 26        NaN       NaN      NaN       ...             7,647     7,638
# 27        NaN       NaN      NaN       ...             1,148       684
# 28      2,581       1.0       0%       ...             7,842        57
# 29        NaN       NaN      NaN       ...               215       172
# ..        ...       ...      ...       ...               ...       ...
# 37        NaN       NaN      NaN       ...             3,289     1,470
# 38        NaN       NaN      NaN       ...             6,897     4,647
# 39        NaN       NaN      NaN       ...            24,857     6,245
# 40        NaN       NaN      NaN       ...            73,611    49,184
# 41        NaN       NaN      NaN       ...               NaN       NaN
# 42        NaN       NaN      NaN       ...               NaN       NaN
# 43        NaN       NaN      NaN       ...            32,500    21,666
# 44        NaN       NaN      NaN       ...             6,920     6,839
# 45     92,602     110.0       0%       ...            15,809         0
# 46        NaN       NaN      NaN       ...             2,790     2,790
# 47        NaN       NaN      NaN       ...               NaN       NaN
# 48        NaN       NaN      NaN       ...               914       746
# 49        NaN       NaN      NaN       ...               NaN       NaN
# 50        NaN       NaN      NaN       ...           106,267    71,990
# 51        NaN       NaN      NaN       ...               NaN       NaN
# 52        NaN       NaN      NaN       ...             5,797     5,410
# 53        NaN       NaN      NaN       ...            21,166    17,648
# 54     68,697       2.0       0%       ...             7,559         0
# 55        NaN       NaN      NaN       ...                35         0
# 56        NaN       NaN      NaN       ...               NaN       NaN
# 57        NaN       NaN      NaN       ...               NaN       NaN
# 58        NaN       NaN      NaN       ...               NaN       NaN
# 59        NaN       NaN      NaN       ...            61,939    18,298
# 60        NaN       NaN      NaN       ...            16,860    15,979
# 61        NaN       NaN      NaN       ...             6,890     5,509
# 62        NaN       NaN      NaN       ...             3,738     3,485
# 63        NaN       NaN      NaN       ...             2,151     1,928
# 64        NaN       NaN      NaN       ...             8,657     3,405
# 65     23,143       4.0       0%       ...            36,333        48
# 66      6,481     232.0       4%       ...             6,609     1,014
#
#    coops_pct muni_total muni_out muni_pct overall_out overall_total  \
# 0        86%    100,626   42,321      42%      66,634       130,032
# 1        98%        NaN      NaN      NaN      10,292        11,363
# 2         1%        NaN      NaN      NaN       1,503       115,629
# 3        76%      2,685    2,685     100%      11,027        12,649
# 4         4%        NaN      NaN      NaN     225,626       310,644
# 5       100%        NaN      NaN      NaN     629,134       933,354
# 6        15%      1,314      300      23%         816         3,936
# 7        98%        NaN      NaN      NaN      66,710       114,958
# 8        86%        NaN      NaN      NaN      69,065        87,714
# 9        66%     13,883    6,042      44%      59,720        94,839
# 10      100%        NaN      NaN      NaN     236,141       245,911
# 11       87%        NaN      NaN      NaN      30,734        33,363
# 12       87%        NaN      NaN      NaN      14,802        17,565
# 13       70%        NaN      NaN      NaN       6,790        10,017
# 14      100%    449,815  252,591      56%     252,618       449,842
# 15        0%        NaN      NaN      NaN          78       156,136
# 16      100%        NaN      NaN      NaN      49,656        58,019
# 17       NaN        NaN      NaN      NaN       5,775        10,202
# 18       58%      7,322      136       2%       8,790        22,294
# 19       78%        NaN      NaN      NaN       6,614         8,900
# 20      100%        912      912     100%       6,272         7,254
# 21       19%        NaN      NaN      NaN       4,437        10,909
# 22       83%        NaN      NaN      NaN       4,848         6,712
# 23       85%      2,734    2,734     100%      11,275        12,291
# 24      100%      4,272    4,272     100%      18,750        18,750
# 25       60%        NaN      NaN      NaN      57,898        94,940
# 26      100%        NaN      NaN      NaN      62,010        62,456
# 27       60%        NaN      NaN      NaN     263,209       632,953
# 28        1%        NaN      NaN      NaN          58        10,423
# 29       80%     35,030   25,790      74%      68,202        91,545
# ..       ...        ...      ...      ...         ...           ...
# 37       45%        NaN      NaN      NaN       1,471         4,058
# 38       67%        NaN      NaN      NaN       6,890        10,708
# 39       25%        NaN      NaN      NaN     112,865       209,757
# 40       67%     49,955   40,742      82%     144,439       189,091
# 41       NaN        NaN      NaN      NaN      69,870        93,400
# 42       NaN     23,086   21,000      91%     823,430     1,137,086
# 43       67%     31,183   31,183     100%      52,939        63,773
# 44       99%        NaN      NaN      NaN      43,735        44,796
# 45        0%        NaN      NaN      NaN         110       108,411
# 46      100%        NaN      NaN      NaN      21,990        22,790
# 47       NaN    211,091  130,143      62%     356,381       580,272
# 48       82%    103,742   40,267      39%      65,002       152,731
# 49       NaN     27,847   24,500      88%     533,990       766,847
# 50       68%        NaN      NaN      NaN     189,194       270,095
# 51       NaN        NaN      NaN      NaN     429,202       551,917
# 52       93%    139,134   84,695      61%     207,236       330,732
# 53       83%        NaN      NaN      NaN      36,568        41,266
# 54        0%        NaN      NaN      NaN           2        76,256
# 55        0%        NaN      NaN      NaN     170,120       263,835
# 56       NaN        NaN      NaN      NaN     157,905       210,503
# 57       NaN     43,969   31,200      71%     107,130       130,769
# 58       NaN     27,630   15,966      58%     108,956       153,830
# 59       30%      1,500    1,500     100%      28,587        73,610
# 60       95%        NaN      NaN      NaN      20,975        22,757
# 61       80%        NaN      NaN      NaN       9,000        12,916
# 62       93%        NaN      NaN      NaN       4,635         5,438
# 63       90%     26,539   26,539     100%     222,328       286,545
# 64       39%        NaN      NaN      NaN       7,249        15,471
# 65        0%        NaN      NaN      NaN          52        59,476
# 66       15%        NaN      NaN      NaN       1,246        13,090
#
#    overall_with_pct overall_out_pct
# 0               49%             51%
# 1                9%             91%
# 2               99%              1%
# 3               13%             87%
# 4               27%             73%
# 5               33%             67%
# 6               79%             21%
# 7               42%             58%
# 8               21%             79%
# 9               37%             63%
# 10               4%             96%
# 11               8%             92%
# 12              16%             84%
# 13              32%             68%
# 14              44%             56%
# 15             100%              0%
# 16              14%             86%
# 17              43%             57%
# 18              61%             39%
# 19              26%             74%
# 20              14%             86%
# 21              59%             41%
# 22              28%             72%
# 23               8%             92%
# 24               0%            100%
# 25              39%             61%
# 26               1%             99%
# 27              58%             42%
# 28              99%              1%
# 29              25%             75%
# ..              ...             ...
# 37              64%             36%
# 38              36%             64%
# 39              46%             54%
# 40              24%             76%
# 41              25%             75%
# 42              28%             72%
# 43              17%             83%
# 44               2%             98%
# 45             100%              0%
# 46               4%             96%
# 47              39%             61%
# 48              57%             43%
# 49              30%             70%
# 50              30%             70%
# 51              22%             78%
# 52              37%             63%
# 53              11%             89%
# 54             100%              0%
# 55              36%             64%
# 56              25%             75%
# 57              18%             82%
# 58              29%             71%
# 59              61%             39%
# 60               8%             92%
# 61              30%             70%
# 62              15%             85%
# 63              22%             78%
# 64              53%             47%
# 65             100%              0%
# 66              90%             10%
#
# [67 rows x 26 columns]

# %%
df_latestClean['county_name'] = df_latestClean['county_name'].apply(properCase)
df_latestClean
# Out:
#      county_name  fpl_total  fpl_out fpl_out_pct duke_total duke_out duke_pct  \
# 0        Alachua      1,300    1,300        100%      4,880    3,056      63%
# 1          Baker      5,400    4,460         83%        NaN      NaN      NaN
# 2            Bay        NaN      NaN         NaN      2,273    1,241      55%
# 3       Bradford      4,100    3,870         94%        NaN      NaN      NaN
# 4        Brevard    307,600  225,490         73%         16        9      56%
# 5        Broward    933,300  629,080         67%        NaN      NaN      NaN
# 6        Calhoun        NaN      NaN         NaN        NaN      NaN      NaN
# 7      Charlotte    114,100   65,870         58%        NaN      NaN      NaN
# 8         Citrus        NaN      NaN         NaN     46,697   33,755      72%
# 9           Clay        900      900        100%        NaN      NaN      NaN
# 10       Collier    210,700  200,930         95%        NaN      NaN      NaN
# 11      Columbia     14,000   14,000        100%        566      323      57%
# 12        DeSoto     16,600   13,960         84%        NaN      NaN      NaN
# 13         Dixie        NaN      NaN         NaN      1,800    1,057      59%
# 14         Duval         10       10        100%        NaN      NaN      NaN
# 15      Escambia        NaN      NaN         NaN        NaN      NaN      NaN
# 16       Flagler     58,000   49,640         86%         16       13      81%
# 17      Franklin        NaN      NaN         NaN     10,202    5,775      57%
# 18       Gadsden        NaN      NaN         NaN        NaN      NaN      NaN
# 19     Gilchrist        NaN      NaN         NaN      1,637      936      57%
# 20        Glades      3,400    2,420         71%        NaN      NaN      NaN
# 21          Gulf        NaN      NaN         NaN      6,470    3,602      56%
# 22      Hamilton        NaN      NaN         NaN      2,927    1,723      59%
# 23        Hardee         40       30         75%      2,671    2,671     100%
# 24        Hendry      9,700    9,700        100%        NaN      NaN      NaN
# 25      Hernando        NaN      NaN         NaN     11,341    7,618      67%
# 26     Highlands        600      420         70%     54,209   53,952     100%
# 27  Hillsborough        NaN      NaN         NaN         25       19      76%
# 28        Holmes        NaN      NaN         NaN        NaN      NaN      NaN
# 29  Indian River     56,300   42,240         75%        NaN      NaN      NaN
# ..           ...        ...      ...         ...        ...      ...      ...
# 37       Liberty        NaN      NaN         NaN        NaN      NaN      NaN
# 38       Madison        NaN      NaN         NaN      3,811    2,243      59%
# 39       Manatee    184,900  106,620         58%        NaN      NaN      NaN
# 40        Marion        NaN      NaN         NaN     65,525   54,513      83%
# 41        Martin     93,400   69,870         75%        NaN      NaN      NaN
# 42    Miami-Dade  1,114,000  802,430         72%        NaN      NaN      NaN
# 43        Monroe         90       90        100%        NaN      NaN      NaN
# 44        Nassau     21,800   20,820         96%        NaN      NaN      NaN
# 45      Okaloosa        NaN      NaN         NaN        NaN      NaN      NaN
# 46    Okeechobee     20,000   19,200         96%        NaN      NaN      NaN
# 47        Orange         10       10        100%    369,171  226,228      61%
# 48       Osceola         10       10        100%     48,065   23,979      50%
# 49    Palm Beach    739,000  509,490         69%        NaN      NaN      NaN
# 50         Pasco        NaN      NaN         NaN    139,992  102,846      73%
# 51      Pinellas        NaN      NaN         NaN    540,933  428,475      79%
# 52          Polk        NaN      NaN         NaN    100,519   66,469      66%
# 53        Putnam     20,100   18,920         94%        NaN      NaN      NaN
# 54    Santa Rosa        NaN      NaN         NaN        NaN      NaN      NaN
# 55      Sarasota    263,800  170,120         64%        NaN      NaN      NaN
# 56      Seminole     54,400   41,650         77%    156,103  116,255      74%
# 57     St. Johns     86,800   75,930         87%        NaN      NaN      NaN
# 58     St. Lucie    126,200   92,990         74%        NaN      NaN      NaN
# 59        Sumter        NaN      NaN         NaN     10,171    8,789      86%
# 60      Suwannee      5,100    4,530         89%        797      466      58%
# 61        Taylor        NaN      NaN         NaN      6,026    3,491      58%
# 62         Union      1,700    1,150         68%        NaN      NaN      NaN
# 63       Volusia    176,800  125,730         71%     81,055   68,131      84%
# 64       Wakulla        NaN      NaN         NaN      6,814    3,844      56%
# 65        Walton        NaN      NaN         NaN        NaN      NaN      NaN
# 66    Washington        NaN      NaN         NaN        NaN      NaN      NaN
#
#    gulf_total  gulf_out gulf_pct       ...       coops_total coops_out  \
# 0         NaN       NaN      NaN       ...            23,226    19,957
# 1         NaN       NaN      NaN       ...             5,963     5,832
# 2     101,709     101.0       0%       ...            11,647       161
# 3         NaN       NaN      NaN       ...             5,864     4,472
# 4         NaN       NaN      NaN       ...             3,028       127
# 5         NaN       NaN      NaN       ...                54        54
# 6         NaN       NaN      NaN       ...             1,697       262
# 7         NaN       NaN      NaN       ...               858       840
# 8         NaN       NaN      NaN       ...            41,017    35,310
# 9         NaN       NaN      NaN       ...            80,056    52,778
# 10        NaN       NaN      NaN       ...            35,211    35,211
# 11        NaN       NaN      NaN       ...            18,797    16,411
# 12        NaN       NaN      NaN       ...               965       842
# 13        NaN       NaN      NaN       ...             8,217     5,733
# 14        NaN       NaN      NaN       ...                17        17
# 15    152,699      78.0       0%       ...             3,437         0
# 16        NaN       NaN      NaN       ...                 3         3
# 17        NaN       NaN      NaN       ...               NaN       NaN
# 18        NaN       NaN      NaN       ...            14,972     8,654
# 19        NaN       NaN      NaN       ...             7,263     5,678
# 20        NaN       NaN      NaN       ...             2,942     2,940
# 21        NaN       NaN      NaN       ...             4,439       835
# 22        NaN       NaN      NaN       ...             3,785     3,125
# 23        NaN       NaN      NaN       ...             6,846     5,840
# 24        NaN       NaN      NaN       ...             4,778     4,778
# 25        NaN       NaN      NaN       ...            83,599    50,280
# 26        NaN       NaN      NaN       ...             7,647     7,638
# 27        NaN       NaN      NaN       ...             1,148       684
# 28      2,581       1.0       0%       ...             7,842        57
# 29        NaN       NaN      NaN       ...               215       172
# ..        ...       ...      ...       ...               ...       ...
# 37        NaN       NaN      NaN       ...             3,289     1,470
# 38        NaN       NaN      NaN       ...             6,897     4,647
# 39        NaN       NaN      NaN       ...            24,857     6,245
# 40        NaN       NaN      NaN       ...            73,611    49,184
# 41        NaN       NaN      NaN       ...               NaN       NaN
# 42        NaN       NaN      NaN       ...               NaN       NaN
# 43        NaN       NaN      NaN       ...            32,500    21,666
# 44        NaN       NaN      NaN       ...             6,920     6,839
# 45     92,602     110.0       0%       ...            15,809         0
# 46        NaN       NaN      NaN       ...             2,790     2,790
# 47        NaN       NaN      NaN       ...               NaN       NaN
# 48        NaN       NaN      NaN       ...               914       746
# 49        NaN       NaN      NaN       ...               NaN       NaN
# 50        NaN       NaN      NaN       ...           106,267    71,990
# 51        NaN       NaN      NaN       ...               NaN       NaN
# 52        NaN       NaN      NaN       ...             5,797     5,410
# 53        NaN       NaN      NaN       ...            21,166    17,648
# 54     68,697       2.0       0%       ...             7,559         0
# 55        NaN       NaN      NaN       ...                35         0
# 56        NaN       NaN      NaN       ...               NaN       NaN
# 57        NaN       NaN      NaN       ...               NaN       NaN
# 58        NaN       NaN      NaN       ...               NaN       NaN
# 59        NaN       NaN      NaN       ...            61,939    18,298
# 60        NaN       NaN      NaN       ...            16,860    15,979
# 61        NaN       NaN      NaN       ...             6,890     5,509
# 62        NaN       NaN      NaN       ...             3,738     3,485
# 63        NaN       NaN      NaN       ...             2,151     1,928
# 64        NaN       NaN      NaN       ...             8,657     3,405
# 65     23,143       4.0       0%       ...            36,333        48
# 66      6,481     232.0       4%       ...             6,609     1,014
#
#    coops_pct muni_total muni_out muni_pct overall_out overall_total  \
# 0        86%    100,626   42,321      42%      66,634       130,032
# 1        98%        NaN      NaN      NaN      10,292        11,363
# 2         1%        NaN      NaN      NaN       1,503       115,629
# 3        76%      2,685    2,685     100%      11,027        12,649
# 4         4%        NaN      NaN      NaN     225,626       310,644
# 5       100%        NaN      NaN      NaN     629,134       933,354
# 6        15%      1,314      300      23%         816         3,936
# 7        98%        NaN      NaN      NaN      66,710       114,958
# 8        86%        NaN      NaN      NaN      69,065        87,714
# 9        66%     13,883    6,042      44%      59,720        94,839
# 10      100%        NaN      NaN      NaN     236,141       245,911
# 11       87%        NaN      NaN      NaN      30,734        33,363
# 12       87%        NaN      NaN      NaN      14,802        17,565
# 13       70%        NaN      NaN      NaN       6,790        10,017
# 14      100%    449,815  252,591      56%     252,618       449,842
# 15        0%        NaN      NaN      NaN          78       156,136
# 16      100%        NaN      NaN      NaN      49,656        58,019
# 17       NaN        NaN      NaN      NaN       5,775        10,202
# 18       58%      7,322      136       2%       8,790        22,294
# 19       78%        NaN      NaN      NaN       6,614         8,900
# 20      100%        912      912     100%       6,272         7,254
# 21       19%        NaN      NaN      NaN       4,437        10,909
# 22       83%        NaN      NaN      NaN       4,848         6,712
# 23       85%      2,734    2,734     100%      11,275        12,291
# 24      100%      4,272    4,272     100%      18,750        18,750
# 25       60%        NaN      NaN      NaN      57,898        94,940
# 26      100%        NaN      NaN      NaN      62,010        62,456
# 27       60%        NaN      NaN      NaN     263,209       632,953
# 28        1%        NaN      NaN      NaN          58        10,423
# 29       80%     35,030   25,790      74%      68,202        91,545
# ..       ...        ...      ...      ...         ...           ...
# 37       45%        NaN      NaN      NaN       1,471         4,058
# 38       67%        NaN      NaN      NaN       6,890        10,708
# 39       25%        NaN      NaN      NaN     112,865       209,757
# 40       67%     49,955   40,742      82%     144,439       189,091
# 41       NaN        NaN      NaN      NaN      69,870        93,400
# 42       NaN     23,086   21,000      91%     823,430     1,137,086
# 43       67%     31,183   31,183     100%      52,939        63,773
# 44       99%        NaN      NaN      NaN      43,735        44,796
# 45        0%        NaN      NaN      NaN         110       108,411
# 46      100%        NaN      NaN      NaN      21,990        22,790
# 47       NaN    211,091  130,143      62%     356,381       580,272
# 48       82%    103,742   40,267      39%      65,002       152,731
# 49       NaN     27,847   24,500      88%     533,990       766,847
# 50       68%        NaN      NaN      NaN     189,194       270,095
# 51       NaN        NaN      NaN      NaN     429,202       551,917
# 52       93%    139,134   84,695      61%     207,236       330,732
# 53       83%        NaN      NaN      NaN      36,568        41,266
# 54        0%        NaN      NaN      NaN           2        76,256
# 55        0%        NaN      NaN      NaN     170,120       263,835
# 56       NaN        NaN      NaN      NaN     157,905       210,503
# 57       NaN     43,969   31,200      71%     107,130       130,769
# 58       NaN     27,630   15,966      58%     108,956       153,830
# 59       30%      1,500    1,500     100%      28,587        73,610
# 60       95%        NaN      NaN      NaN      20,975        22,757
# 61       80%        NaN      NaN      NaN       9,000        12,916
# 62       93%        NaN      NaN      NaN       4,635         5,438
# 63       90%     26,539   26,539     100%     222,328       286,545
# 64       39%        NaN      NaN      NaN       7,249        15,471
# 65        0%        NaN      NaN      NaN          52        59,476
# 66       15%        NaN      NaN      NaN       1,246        13,090
#
#    overall_with_pct overall_out_pct
# 0               49%             51%
# 1                9%             91%
# 2               99%              1%
# 3               13%             87%
# 4               27%             73%
# 5               33%             67%
# 6               79%             21%
# 7               42%             58%
# 8               21%             79%
# 9               37%             63%
# 10               4%             96%
# 11               8%             92%
# 12              16%             84%
# 13              32%             68%
# 14              44%             56%
# 15             100%              0%
# 16              14%             86%
# 17              43%             57%
# 18              61%             39%
# 19              26%             74%
# 20              14%             86%
# 21              59%             41%
# 22              28%             72%
# 23               8%             92%
# 24               0%            100%
# 25              39%             61%
# 26               1%             99%
# 27              58%             42%
# 28              99%              1%
# 29              25%             75%
# ..              ...             ...
# 37              64%             36%
# 38              36%             64%
# 39              46%             54%
# 40              24%             76%
# 41              25%             75%
# 42              28%             72%
# 43              17%             83%
# 44               2%             98%
# 45             100%              0%
# 46               4%             96%
# 47              39%             61%
# 48              57%             43%
# 49              30%             70%
# 50              30%             70%
# 51              22%             78%
# 52              37%             63%
# 53              11%             89%
# 54             100%              0%
# 55              36%             64%
# 56              25%             75%
# 57              18%             82%
# 58              29%             71%
# 59              61%             39%
# 60               8%             92%
# 61              30%             70%
# 62              15%             85%
# 63              22%             78%
# 64              53%             47%
# 65             100%              0%
# 66              90%             10%
#
# [67 rows x 26 columns]

# %%
df_dataMerge = df_fips.merge(df_latestClean,on='county_name',how='outer')
df_dataMerge = df_dataMerge.rename(columns={'fips_code':'county_fips'})
df_dataMerge
df_dataMerge.to_csv('data/finalData.csv')
